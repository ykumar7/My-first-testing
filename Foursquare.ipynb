# %%
### Import necessary Libraries

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/DSX-Python35
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2018.8.24          |        py35_1001         139 KB  conda-forge
#     openssl-1.0.2r             |       h14c3975_0         3.1 MB  conda-forge
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     ca-certificates-2019.6.16  |       hecc5488_0         145 KB  conda-forge
#     geographiclib-1.49         |             py_0          32 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.49-py_0         conda-forge
#     geopy:           1.20.0-py_0       conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.1.23-0                   --> 2019.6.16-hecc5488_0 conda-forge
#     certifi:         2018.8.24-py35_1              --> 2018.8.24-py35_1001  conda-forge
#
# The following packages will be DOWNGRADED:
#
#     openssl:         1.0.2s-h7b6447c_0             --> 1.0.2r-h14c3975_0    conda-forge
#
#
# Downloading and Extracting Packages
# certifi-2018.8.24    | 139 KB    | ##################################### | 100%
# openssl-1.0.2r       | 3.1 MB    | ##################################### | 100%
# geopy-1.20.0         | 57 KB     | ##################################### | 100%
# ca-certificates-2019 | 145 KB    | ##################################### | 100%
# geographiclib-1.49   | 32 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/DSX-Python35
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-2.2.2               |           py35_1         462 KB  conda-forge
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         560 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  2.2.2-py35_1 conda-forge
#     branca:  0.3.1-py_0   conda-forge
#     folium:  0.5.0-py_0   conda-forge
#     vincent: 0.4.4-py_1   conda-forge
#
#
# Downloading and Extracting Packages
# altair-2.2.2         | 462 KB    | ##################################### | 100%
# branca-0.3.1         | 25 KB     | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = 'HRYCYRRH44B02GOSP1MNOVC1AVLFQTAIT1ZFSSMIXBAFXF13' # your Foursquare ID
CLIENT_SECRET = 'MGW2M22FVAXDIIQOE42J55BRE0KCCSYLEUHPT3JOBICD55OR' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: HRYCYRRH44B02GOSP1MNOVC1AVLFQTAIT1ZFSSMIXBAFXF13
# CLIENT_SECRET:MGW2M22FVAXDIIQOE42J55BRE0KCCSYLEUHPT3JOBICD55OR

# %%
address = 'London'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 51.5073219 -0.1276474

# %%
latitude = 51.5073219
longitude = -0.1276474

# %%
search_query = 'Science Parks'
radius = 50000
print(search_query + ' .... OK!')
# Out:
# Science Parks .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=HRYCYRRH44B02GOSP1MNOVC1AVLFQTAIT1ZFSSMIXBAFXF13&client_secret=MGW2M22FVAXDIIQOE42J55BRE0KCCSYLEUHPT3JOBICD55OR&ll=51.5073219,-0.1276474&v=20180604&query=Science Parks&radius=50000&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d18904c5d891b00395e804d'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_science_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d191941735',
#       'name': 'Science Museum',
#       'pluralName': 'Science Museums',
#       'primary': True,
#       'shortName': 'Science Museum'}],
#     'hasPerk': False,
#     'id': '4ac518cdf964a520e9a520e3',
#     'location': {'address': 'Exhibition Rd',
#      'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'distance': 3426,
#      'formattedAddress': ['Exhibition Rd',
#       'London',
#       'Greater London',
#       'SW7 2DD',
#       'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.49735805798784,
#        'lng': -0.17443418552973236}],
#      'lat': 51.49735805798784,
#      'lng': -0.17443418552973236,
#      'neighborhood': 'South Kensington',
#      'postalCode': 'SW7 2DD',
#      'state': 'Greater London'},
#     'name': 'Science Museum',
#     'referralId': 'v-1561890892',
#     'venuePage': {'id': '44780007'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_science_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d191941735',
#       'name': 'Science Museum',
#       'pluralName': 'Science Museums',
#       'primary': True,
#       'shortName': 'Science Museum'}],
#     'hasPerk': False,
#     'id': '54421c23498e3db5fc823d25',
#     'location': {'address': 'Great Maze Pond',
#      'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'distance': 2810,
#      'formattedAddress': ['Great Maze Pond',
#       'London',
#       'Greater London',
#       'SE1 9GU',
#       'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.50420126531229,
#        'lng': -0.08740165960691129}],
#      'lat': 51.50420126531229,
#      'lng': -0.08740165960691129,
#      'postalCode': 'SE1 9GU',
#      'state': 'Greater London'},
#     'name': 'Science Gallery London',
#     'referralId': 'v-1561890892'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1ae941735',
#       'name': 'University',
#       'pluralName': 'Universities',
#       'primary': True,
#       'shortName': 'University'}],
#     'hasPerk': False,
#     'id': '4af1a842f964a520e5e121e3',
#     'location': {'address': 'Houghton St',
#      'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'crossStreet': 'Portugal St',
#      'distance': 1119,
#      'formattedAddress': ['Houghton St (Portugal St)',
#       'London',
#       'Greater London',
#       'WC2A 2AE',
#       'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.51466435365831,
#        'lng': -0.11660099029541014}],
#      'lat': 51.51466435365831,
#      'lng': -0.11660099029541014,
#      'postalCode': 'WC2A 2AE',
#      'state': 'Greater London'},
#     'name': 'London School of Economics and Political Science (LSE)',
#     'referralId': 'v-1561890892'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/library_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1a7941735',
#       'name': 'College Library',
#       'pluralName': 'College Libraries',
#       'primary': True,
#       'shortName': 'Library'}],
#     'hasPerk': False,
#     'id': '4b92941df964a520370634e3',
#     'location': {'address': 'DMS Watson Building, Malet Pl',
#      'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'distance': 1828,
#      'formattedAddress': ['DMS Watson Building, Malet Pl',
#       'London',
#       'Greater London',
#       'WC1E 6BT',
#       'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.52342396197303,
#        'lng': -0.13282847171120712}],
#      'lat': 51.52342396197303,
#      'lng': -0.13282847171120712,
#      'postalCode': 'WC1E 6BT',
#      'state': 'Greater London'},
#     'name': 'UCL Science Library',
#     'referralId': 'v-1561890892'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d17f941735',
#       'name': 'Movie Theater',
#       'pluralName': 'Movie Theaters',
#       'primary': True,
#       'shortName': 'Movie Theater'}],
#     'events': {'count': 4, 'summary': '4 movies'},
#     'hasPerk': False,
#     'id': '4beb261ff90e9c744480e3ed',
#     'location': {'address': 'Exhibition Rd',
#      'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'distance': 3660,
#      'formattedAddress': ['Exhibition Rd',
#       'London',
#       'Greater London',
#       'SW7 2DD',
#       'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.49716450794273,
#        'lng': -0.17789270697050005}],
#      'lat': 51.49716450794273,
#      'lng': -0.17789270697050005,
#      'postalCode': 'SW7 2DD',
#      'state': 'Greater London'},
#     'name': 'Science Museum (IMAX)',
#     'referralId': 'v-1561890892'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/classroom_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1a0941735',
#       'name': 'College Classroom',
#       'pluralName': 'College Classrooms',
#       'primary': True,
#       'shortName': 'Classroom'}],
#     'hasPerk': False,
#     'id': '4fa10925e4b0ebb3531a6006',
#     'location': {'cc': 'GB',
#      'country': 'United Kingdom',
#      'distance': 1286,
#      'formattedAddress': ['United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.518348,
#        'lng': -0.122064}],
#      'lat': 51.518348,
#      'lng': -0.122064},
#     'name': 'Science Lab',
#     'referralId': 'v-1561890892'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'primary': True,
#       'shortName': 'Café'}],
#     'hasPerk': False,
#     'id': '5c2f52e475dcb7002c5c86c2',
#     'location': {'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'distance': 2796,
#      'formattedAddress': ['London', 'Greater London', 'SE1', 'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.504265,
#        'lng': -0.08759357}],
#      'lat': 51.504265,
#      'lng': -0.08759357,
#      'postalCode': 'SE1',
#      'state': 'Greater London'},
#     'name': 'Science Gallery Café',
#     'referralId': 'v-1561890892'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'primary': True,
#       'shortName': 'Office'}],
#     'hasPerk': False,
#     'id': '58dbb70883622d650986cc3d',
#     'location': {'address': '14 Warbeck street',
#      'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'distance': 1856,
#      'formattedAddress': ['14 Warbeck street',
#       'London',
#       'Greater London',
#       'W1G 9XU',
#       'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.517243,
#        'lng': -0.14918}],
#      'lat': 51.517243,
#      'lng': -0.14918,
#      'postalCode': 'W1G 9XU',
#      'state': 'Greater London'},
#     'name': 'Science',
#     'referralId': 'v-1561890892'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/library_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1a7941735',
#       'name': 'College Library',
#       'pluralName': 'College Libraries',
#       'primary': True,
#       'shortName': 'Library'}],
#     'hasPerk': False,
#     'id': '4b76e42cf964a520ba672ee3',
#     'location': {'address': '10 Portugal St',
#      'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'distance': 1167,
#      'formattedAddress': ['10 Portugal St',
#       'London',
#       'Greater London',
#       'WC2A 2HD',
#       'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.514705144154576,
#        'lng': -0.11567831039428711}],
#      'lat': 51.514705144154576,
#      'lng': -0.11567831039428711,
#      'postalCode': 'WC2A 2HD',
#      'state': 'Greater London'},
#     'name': 'LSE Library',
#     'referralId': 'v-1561890892',
#     'venuePage': {'id': '399888849'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/giftshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d128951735',
#       'name': 'Gift Shop',
#       'pluralName': 'Gift Shops',
#       'primary': True,
#       'shortName': 'Gift Shop'}],
#     'hasPerk': False,
#     'id': '4c5d480e85a1e21ee0ed5811',
#     'location': {'address': 'Exhibition Rd',
#      'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'distance': 3413,
#      'formattedAddress': ['Exhibition Rd',
#       'London',
#       'Greater London',
#       'SW7 2DD',
#       'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.49739262176734,
#        'lng': -0.1742492464365554}],
#      'lat': 51.49739262176734,
#      'lng': -0.1742492464365554,
#      'postalCode': 'SW7 2DD',
#      'state': 'Greater London'},
#     'name': 'Science Museum Shop',
#     'referralId': 'v-1561890892'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'primary': True,
#       'shortName': 'Office'}],
#     'hasPerk': False,
#     'id': '53eb0b7a498e7f61e4f5c9ba',
#     'location': {'cc': 'GB',
#      'country': 'United Kingdom',
#      'distance': 345,
#      'formattedAddress': ['United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.504662,
#        'lng': -0.130217}],
#      'lat': 51.504662,
#      'lng': -0.130217},
#     'name': 'Royal Parks Office - St James',
#     'referralId': 'v-1561890892'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_science_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d191941735',
#       'name': 'Science Museum',
#       'pluralName': 'Science Museums',
#       'primary': True,
#       'shortName': 'Science Museum'}],
#     'hasPerk': False,
#     'id': '4f65fbd5e4b0ce431e84619a',
#     'location': {'address': 'Exhibition Rd',
#      'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'distance': 3656,
#      'formattedAddress': ['Exhibition Rd',
#       'London',
#       'Greater London',
#       'SW7 2DD',
#       'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.49718901346113,
#        'lng': -0.17783717222353052}],
#      'lat': 51.49718901346113,
#      'lng': -0.17783717222353052,
#      'postalCode': 'SW7 2DD',
#      'state': 'Greater London'},
#     'name': 'Science Museum Gallery of Flight',
#     'referralId': 'v-1561890892'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'primary': True,
#       'shortName': 'Office'}],
#     'hasPerk': False,
#     'id': '4ee077cce5fa0be346679396',
#     'location': {'address': '215 Euston Road',
#      'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'distance': 2094,
#      'formattedAddress': ['215 Euston Road',
#       'London',
#       'Greater London',
#       'NW1 2BE',
#       'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.52557470914815,
#        'lng': -0.1349674542741915}],
#      'lat': 51.52557470914815,
#      'lng': -0.1349674542741915,
#      'postalCode': 'NW1 2BE',
#      'state': 'Greater London'},
#     'name': 'Science Media Centre',
#     'referralId': 'v-1561890892'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'primary': True,
#       'shortName': 'Building'}],
#     'hasPerk': False,
#     'id': '528cc10f11d280a7af225d00',
#     'location': {'address': 'c/o Royal Society of Chemistry, Burlington House',
#      'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'crossStreet': 'Piccadilly',
#      'distance': 2984,
#      'formattedAddress': ['c/o Royal Society of Chemistry, Burlington House (Piccadilly)',
#       'London',
#       'Greater London',
#       'W1J 0BA',
#       'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.52595028538521,
#        'lng': -0.0966699948276073}],
#      'lat': 51.52595028538521,
#      'lng': -0.0966699948276073,
#      'postalCode': 'W1J 0BA',
#      'state': 'Greater London'},
#     'name': 'The Science Council',
#     'referralId': 'v-1561890892'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'primary': True,
#       'shortName': 'Office'}],
#     'hasPerk': False,
#     'id': '4c3ef85adb3b1b8ddd146695',
#     'location': {'cc': 'GB',
#      'country': 'United Kingdom',
#      'distance': 430,
#      'formattedAddress': ['United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.510429,
#        'lng': -0.12394}],
#      'lat': 51.510429,
#      'lng': -0.12394},
#     'name': 'Audience Science HQ',
#     'referralId': 'v-1561890892'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_science_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d191941735',
#       'name': 'Science Museum',
#       'pluralName': 'Science Museums',
#       'primary': True,
#       'shortName': 'Science Museum'}],
#     'hasPerk': False,
#     'id': '51222524e4b08f84c1651d98',
#     'location': {'address': 'Science Museum',
#      'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'distance': 3407,
#      'formattedAddress': ['Science Museum',
#       'London',
#       'Greater London',
#       'SW7 2DD',
#       'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.497559070416386,
#        'lng': -0.17425646847660334}],
#      'lat': 51.497559070416386,
#      'lng': -0.17425646847660334,
#      'postalCode': 'SW7 2DD',
#      'state': 'Greater London'},
#     'name': 'Science Museum Launch Pad',
#     'referralId': 'v-1561890892'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_science_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d191941735',
#       'name': 'Science Museum',
#       'pluralName': 'Science Museums',
#       'primary': True,
#       'shortName': 'Science Museum'}],
#     'hasPerk': False,
#     'id': '595f6094f79faa623f5589c3',
#     'location': {'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'distance': 3442,
#      'formattedAddress': ['London', 'Greater London', 'SW7', 'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.497265,
#        'lng': -0.17463294}],
#      'lat': 51.497265,
#      'lng': -0.17463294,
#      'postalCode': 'SW7',
#      'state': 'Greater London'},
#     'name': 'Science Museum Live Wire',
#     'referralId': 'v-1561890892'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#        'suffix': '.png'},
#       'id': '507c8c4091d498d9fc8c67a9',
#       'name': 'Public Art',
#       'pluralName': 'Public Art',
#       'primary': True,
#       'shortName': 'Public Art'}],
#     'hasPerk': False,
#     'id': '523d8e2a11d22f1ce9d27df7',
#     'location': {'cc': 'GB',
#      'country': 'United Kingdom',
#      'distance': 3460,
#      'formattedAddress': ['United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.496516643696495,
#        'lng': -0.17447610411033818}],
#      'lat': 51.496516643696495,
#      'lng': -0.17447610411033818},
#     'name': 'Science Museum Virgin Media Studio',
#     'referralId': 'v-1561890892'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/collegeacademicbuildings_science_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d19b941735',
#       'name': 'College Science Building',
#       'pluralName': 'College Science Buildings',
#       'primary': True,
#       'shortName': 'Science'}],
#     'hasPerk': False,
#     'id': '50ed8259e4b06915b47660f2',
#     'location': {'address': '22 Gordon Sq.',
#      'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'distance': 1926,
#      'formattedAddress': ['22 Gordon Sq.',
#       'London',
#       'Greater London',
#       'WC1E 6BT',
#       'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.524409,
#        'lng': -0.132057}],
#      'lat': 51.524409,
#      'lng': -0.132057,
#      'postalCode': 'WC1E 6BT',
#      'state': 'Greater London'},
#     'name': 'Department of Science and Technology Studies UCL',
#     'referralId': 'v-1561890892'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'primary': True,
#       'shortName': 'Church'}],
#     'hasPerk': False,
#     'id': '4ef71d5b0e61a0846d386d49',
#     'location': {'address': '7 Curzon Street',
#      'cc': 'GB',
#      'city': 'Mayfair',
#      'country': 'United Kingdom',
#      'distance': 1288,
#      'formattedAddress': ['7 Curzon Street',
#       'Mayfair',
#       'Greater London',
#       'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.5069938037823,
#        'lng': -0.14623604313682573}],
#      'lat': 51.5069938037823,
#      'lng': -0.14623604313682573,
#      'state': 'Greater London'},
#     'name': 'Third Church Of Christ Science',
#     'referralId': 'v-1561890892'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'primary': True,
#       'shortName': 'Office'}],
#     'hasPerk': False,
#     'id': '4e5e17ed22718258c488dde8',
#     'location': {'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'distance': 5324,
#      'formattedAddress': ['London', 'Greater London', 'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.523705,
#        'lng': -0.199853}],
#      'lat': 51.523705,
#      'lng': -0.199853,
#      'state': 'Greater London'},
#     'name': 'Science Photo Libraru',
#     'referralId': 'v-1561890892'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/collegeacademicbuildings_science_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d19b941735',
#       'name': 'College Science Building',
#       'pluralName': 'College Science Buildings',
#       'primary': True,
#       'shortName': 'Science'}],
#     'hasPerk': False,
#     'id': '524ebf31498e6881221ca459',
#     'location': {'address': '29 Hornsey Road',
#      'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'distance': 5263,
#      'formattedAddress': ['29 Hornsey Road',
#       'London',
#       'Greater London',
#       'N7 7DD',
#       'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.55350923390426,
#        'lng': -0.11138797307215326}],
#      'lat': 51.55350923390426,
#      'lng': -0.11138797307215326,
#      'postalCode': 'N7 7DD',
#      'state': 'Greater London'},
#     'name': 'Science Centre',
#     'referralId': 'v-1561890892'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/eventspace_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d171941735',
#       'name': 'Event Space',
#       'pluralName': 'Event Spaces',
#       'primary': True,
#       'shortName': 'Event Space'}],
#     'hasPerk': False,
#     'id': '4f3813d800398129cba67006',
#     'location': {'address': '53 Frith Street',
#      'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'distance': 780,
#      'formattedAddress': ['53 Frith Street',
#       'London',
#       'Greater London',
#       'W1d 4sn',
#       'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.5138438414177,
#        'lng': -0.13179302215576172}],
#      'lat': 51.5138438414177,
#      'lng': -0.13179302215576172,
#      'postalCode': 'W1d 4sn',
#      'state': 'Greater London'},
#     'name': 'Media Science',
#     'referralId': 'v-1561890892'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_policestation_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d12e941735',
#       'name': 'Police Station',
#       'pluralName': 'Police Stations',
#       'primary': True,
#       'shortName': 'Police Station'}],
#     'hasPerk': False,
#     'id': '55683b63498ecc78c0bbffd9',
#     'location': {'cc': 'GB',
#      'country': 'United Kingdom',
#      'distance': 848,
#      'formattedAddress': ['United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.514711846369856,
#        'lng': -0.13065261533946157}],
#      'lat': 51.514711846369856,
#      'lng': -0.13065261533946157},
#     'name': 'Forensic Science Service',
#     'referralId': 'v-1561890892'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/academicbuilding_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d198941735',
#       'name': 'College Academic Building',
#       'pluralName': 'College Academic Buildings',
#       'primary': True,
#       'shortName': 'Academic Building'}],
#     'hasPerk': False,
#     'id': '4add7318f964a520036521e3',
#     'location': {'address': '11 Mandeville Place',
#      'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'distance': 1940,
#      'formattedAddress': ['11 Mandeville Place',
#       'London',
#       'Greater London',
#       'W1U 3AJ',
#       'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.51667965073041,
#        'lng': -0.15128672249982805}],
#      'lat': 51.51667965073041,
#      'lng': -0.15128672249982805,
#      'postalCode': 'W1U 3AJ',
#      'state': 'Greater London'},
#     'name': 'The School of Economic Science',
#     'referralId': 'v-1561890892'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/classroom_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1a0941735',
#       'name': 'College Classroom',
#       'pluralName': 'College Classrooms',
#       'primary': True,
#       'shortName': 'Classroom'}],
#     'hasPerk': False,
#     'id': '4faa5801e4b0b7e221386f18',
#     'location': {'cc': 'GB',
#      'country': 'United Kingdom',
#      'distance': 5546,
#      'formattedAddress': ['United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.46491923087138,
#        'lng': -0.16965409061135697}],
#      'lat': 51.46491923087138,
#      'lng': -0.16965409061135697},
#     'name': 'science class',
#     'referralId': 'v-1561890892'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/hikingtrail_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d159941735',
#       'name': 'Trail',
#       'pluralName': 'Trails',
#       'primary': True,
#       'shortName': 'Trail'}],
#     'hasPerk': False,
#     'id': '4fa041090cd6294ec9eb478d',
#     'location': {'address': 'Bridge Street',
#      'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'crossStreet': 'Victoria Embankment',
#      'distance': 758,
#      'formattedAddress': ['Bridge Street (Victoria Embankment)',
#       'London',
#       'Greater London',
#       'SW1A 2LW',
#       'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.50082216506806,
#        'lng': -0.12434720993041992}],
#      'lat': 51.50082216506806,
#      'lng': -0.12434720993041992,
#      'postalCode': 'SW1A 2LW',
#      'state': 'Greater London'},
#     'name': 'Treasure Walks London Royal Palaces and Parks Tour and Scavenger Hunt',
#     'referralId': 'v-1561890892'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'primary': True,
#       'shortName': 'Office'}],
#     'hasPerk': False,
#     'id': '55d461f1498e82e21348ca0a',
#     'location': {'cc': 'GB',
#      'country': 'United Kingdom',
#      'distance': 782,
#      'formattedAddress': ['United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.510540527481915,
#        'lng': -0.1376896222915555}],
#      'lat': 51.510540527481915,
#      'lng': -0.1376896222915555},
#     'name': 'Integral Ad Science',
#     'referralId': 'v-1561890892'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/library_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1a7941735',
#       'name': 'College Library',
#       'pluralName': 'College Libraries',
#       'primary': True,
#       'shortName': 'Library'}],
#     'hasPerk': False,
#     'id': '4fbbcebce4b0bc54729473d3',
#     'location': {'address': 'British Library',
#      'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'distance': 2442,
#      'formattedAddress': ['British Library',
#       'London',
#       'Greater London',
#       'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.52926447531897,
#        'lng': -0.12731944475765072}],
#      'lat': 51.52926447531897,
#      'lng': -0.12731944475765072,
#      'state': 'Greater London'},
#     'name': 'Social Science Reading Room',
#     'referralId': 'v-1561890892'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/technology_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d125941735',
#       'name': 'Tech Startup',
#       'pluralName': 'Tech Startups',
#       'primary': True,
#       'shortName': 'Tech Startup'}],
#     'hasPerk': False,
#     'id': '511cd850e4b005f41de6c9a5',
#     'location': {'address': '1 Golden Square',
#      'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'distance': 842,
#      'formattedAddress': ['1 Golden Square',
#       'London',
#       'Greater London',
#       'W1F 9DJ',
#       'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.512076,
#        'lng': -0.137109}],
#      'lat': 51.512076,
#      'lng': -0.137109,
#      'postalCode': 'W1F 9DJ',
#      'state': 'Greater London'},
#     'name': 'Gotham Digital Science',
#     'referralId': 'v-1561890892'}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  events.count  \
# 0  [{'pluralName': 'Science Museums', 'primary': ...           NaN
# 1  [{'pluralName': 'Science Museums', 'primary': ...           NaN
# 2  [{'pluralName': 'Universities', 'primary': Tru...           NaN
# 3  [{'pluralName': 'College Libraries', 'primary'...           NaN
# 4  [{'pluralName': 'Movie Theaters', 'primary': T...           4.0
#
#   events.summary  hasPerk                        id  \
# 0            NaN    False  4ac518cdf964a520e9a520e3
# 1            NaN    False  54421c23498e3db5fc823d25
# 2            NaN    False  4af1a842f964a520e5e121e3
# 3            NaN    False  4b92941df964a520370634e3
# 4       4 movies    False  4beb261ff90e9c744480e3ed
#
#                 location.address location.cc location.city location.country  \
# 0                  Exhibition Rd          GB        London   United Kingdom
# 1                Great Maze Pond          GB        London   United Kingdom
# 2                    Houghton St          GB        London   United Kingdom
# 3  DMS Watson Building, Malet Pl          GB        London   United Kingdom
# 4                  Exhibition Rd          GB        London   United Kingdom
#
#   location.crossStreet     ...       \
# 0                  NaN     ...
# 1                  NaN     ...
# 2          Portugal St     ...
# 3                  NaN     ...
# 4                  NaN     ...
#
#                            location.formattedAddress  \
# 0  [Exhibition Rd, London, Greater London, SW7 2D...
# 1  [Great Maze Pond, London, Greater London, SE1 ...
# 2  [Houghton St (Portugal St), London, Greater Lo...
# 3  [DMS Watson Building, Malet Pl, London, Greate...
# 4  [Exhibition Rd, London, Greater London, SW7 2D...
#
#                              location.labeledLatLngs location.lat  \
# 0  [{'lat': 51.49735805798784, 'lng': -0.17443418...    51.497358
# 1  [{'lat': 51.50420126531229, 'lng': -0.08740165...    51.504201
# 2  [{'lat': 51.51466435365831, 'lng': -0.11660099...    51.514664
# 3  [{'lat': 51.52342396197303, 'lng': -0.13282847...    51.523424
# 4  [{'lat': 51.49716450794273, 'lng': -0.17789270...    51.497165
#
#    location.lng  location.neighborhood location.postalCode  location.state  \
# 0     -0.174434       South Kensington             SW7 2DD  Greater London
# 1     -0.087402                    NaN             SE1 9GU  Greater London
# 2     -0.116601                    NaN            WC2A 2AE  Greater London
# 3     -0.132828                    NaN            WC1E 6BT  Greater London
# 4     -0.177893                    NaN             SW7 2DD  Greater London
#
#                                                 name    referralId  \
# 0                                     Science Museum  v-1561890892
# 1                             Science Gallery London  v-1561890892
# 2  London School of Economics and Political Scien...  v-1561890892
# 3                                UCL Science Library  v-1561890892
# 4                              Science Museum (IMAX)  v-1561890892
#
#   venuePage.id
# 0     44780007
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 21 columns]

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                  name  \
# 0                                      Science Museum
# 1                              Science Gallery London
# 2   London School of Economics and Political Scien...
# 3                                 UCL Science Library
# 4                               Science Museum (IMAX)
# 5                                         Science Lab
# 6                                Science Gallery Café
# 7                                             Science
# 8                                         LSE Library
# 9                                 Science Museum Shop
# 10                      Royal Parks Office - St James
# 11                   Science Museum Gallery of Flight
# 12                               Science Media Centre
# 13                                The Science Council
# 14                                Audience Science HQ
# 15                          Science Museum Launch Pad
# 16                           Science Museum Live Wire
# 17                 Science Museum Virgin Media Studio
# 18   Department of Science and Technology Studies UCL
# 19                     Third Church Of Christ Science
# 20                              Science Photo Libraru
# 21                                     Science Centre
# 22                                      Media Science
# 23                           Forensic Science Service
# 24                     The School of Economic Science
# 25                                      science class
# 26  Treasure Walks London Royal Palaces and Parks ...
# 27                                Integral Ad Science
# 28                        Social Science Reading Room
# 29                             Gotham Digital Science
#
#                    categories  \
# 0              Science Museum
# 1              Science Museum
# 2                  University
# 3             College Library
# 4               Movie Theater
# 5           College Classroom
# 6                        Café
# 7                      Office
# 8             College Library
# 9                   Gift Shop
# 10                     Office
# 11             Science Museum
# 12                     Office
# 13                   Building
# 14                     Office
# 15             Science Museum
# 16             Science Museum
# 17                 Public Art
# 18   College Science Building
# 19                     Church
# 20                     Office
# 21   College Science Building
# 22                Event Space
# 23             Police Station
# 24  College Academic Building
# 25          College Classroom
# 26                      Trail
# 27                     Office
# 28            College Library
# 29               Tech Startup
#
#                                              address  cc     city  \
# 0                                      Exhibition Rd  GB   London
# 1                                    Great Maze Pond  GB   London
# 2                                        Houghton St  GB   London
# 3                      DMS Watson Building, Malet Pl  GB   London
# 4                                      Exhibition Rd  GB   London
# 5                                                NaN  GB      NaN
# 6                                                NaN  GB   London
# 7                                  14 Warbeck street  GB   London
# 8                                     10 Portugal St  GB   London
# 9                                      Exhibition Rd  GB   London
# 10                                               NaN  GB      NaN
# 11                                     Exhibition Rd  GB   London
# 12                                   215 Euston Road  GB   London
# 13  c/o Royal Society of Chemistry, Burlington House  GB   London
# 14                                               NaN  GB      NaN
# 15                                    Science Museum  GB   London
# 16                                               NaN  GB   London
# 17                                               NaN  GB      NaN
# 18                                     22 Gordon Sq.  GB   London
# 19                                   7 Curzon Street  GB  Mayfair
# 20                                               NaN  GB   London
# 21                                   29 Hornsey Road  GB   London
# 22                                   53 Frith Street  GB   London
# 23                                               NaN  GB      NaN
# 24                               11 Mandeville Place  GB   London
# 25                                               NaN  GB      NaN
# 26                                     Bridge Street  GB   London
# 27                                               NaN  GB      NaN
# 28                                   British Library  GB   London
# 29                                   1 Golden Square  GB   London
#
#            country          crossStreet  distance  \
# 0   United Kingdom                  NaN      3426
# 1   United Kingdom                  NaN      2810
# 2   United Kingdom          Portugal St      1119
# 3   United Kingdom                  NaN      1828
# 4   United Kingdom                  NaN      3660
# 5   United Kingdom                  NaN      1286
# 6   United Kingdom                  NaN      2796
# 7   United Kingdom                  NaN      1856
# 8   United Kingdom                  NaN      1167
# 9   United Kingdom                  NaN      3413
# 10  United Kingdom                  NaN       345
# 11  United Kingdom                  NaN      3656
# 12  United Kingdom                  NaN      2094
# 13  United Kingdom           Piccadilly      2984
# 14  United Kingdom                  NaN       430
# 15  United Kingdom                  NaN      3407
# 16  United Kingdom                  NaN      3442
# 17  United Kingdom                  NaN      3460
# 18  United Kingdom                  NaN      1926
# 19  United Kingdom                  NaN      1288
# 20  United Kingdom                  NaN      5324
# 21  United Kingdom                  NaN      5263
# 22  United Kingdom                  NaN       780
# 23  United Kingdom                  NaN       848
# 24  United Kingdom                  NaN      1940
# 25  United Kingdom                  NaN      5546
# 26  United Kingdom  Victoria Embankment       758
# 27  United Kingdom                  NaN       782
# 28  United Kingdom                  NaN      2442
# 29  United Kingdom                  NaN       842
#
#                                      formattedAddress  \
# 0   [Exhibition Rd, London, Greater London, SW7 2D...
# 1   [Great Maze Pond, London, Greater London, SE1 ...
# 2   [Houghton St (Portugal St), London, Greater Lo...
# 3   [DMS Watson Building, Malet Pl, London, Greate...
# 4   [Exhibition Rd, London, Greater London, SW7 2D...
# 5                                    [United Kingdom]
# 6       [London, Greater London, SE1, United Kingdom]
# 7   [14 Warbeck street, London, Greater London, W1...
# 8   [10 Portugal St, London, Greater London, WC2A ...
# 9   [Exhibition Rd, London, Greater London, SW7 2D...
# 10                                   [United Kingdom]
# 11  [Exhibition Rd, London, Greater London, SW7 2D...
# 12  [215 Euston Road, London, Greater London, NW1 ...
# 13  [c/o Royal Society of Chemistry, Burlington Ho...
# 14                                   [United Kingdom]
# 15  [Science Museum, London, Greater London, SW7 2...
# 16      [London, Greater London, SW7, United Kingdom]
# 17                                   [United Kingdom]
# 18  [22 Gordon Sq., London, Greater London, WC1E 6...
# 19  [7 Curzon Street, Mayfair, Greater London, Uni...
# 20           [London, Greater London, United Kingdom]
# 21  [29 Hornsey Road, London, Greater London, N7 7...
# 22  [53 Frith Street, London, Greater London, W1d ...
# 23                                   [United Kingdom]
# 24  [11 Mandeville Place, London, Greater London, ...
# 25                                   [United Kingdom]
# 26  [Bridge Street (Victoria Embankment), London, ...
# 27                                   [United Kingdom]
# 28  [British Library, London, Greater London, Unit...
# 29  [1 Golden Square, London, Greater London, W1F ...
#
#                                        labeledLatLngs        lat       lng  \
# 0   [{'lat': 51.49735805798784, 'lng': -0.17443418...  51.497358 -0.174434
# 1   [{'lat': 51.50420126531229, 'lng': -0.08740165...  51.504201 -0.087402
# 2   [{'lat': 51.51466435365831, 'lng': -0.11660099...  51.514664 -0.116601
# 3   [{'lat': 51.52342396197303, 'lng': -0.13282847...  51.523424 -0.132828
# 4   [{'lat': 51.49716450794273, 'lng': -0.17789270...  51.497165 -0.177893
# 5   [{'lat': 51.518348, 'lng': -0.122064, 'label':...  51.518348 -0.122064
# 6   [{'lat': 51.504265, 'lng': -0.08759357, 'label...  51.504265 -0.087594
# 7   [{'lat': 51.517243, 'lng': -0.14918, 'label': ...  51.517243 -0.149180
# 8   [{'lat': 51.514705144154576, 'lng': -0.1156783...  51.514705 -0.115678
# 9   [{'lat': 51.49739262176734, 'lng': -0.17424924...  51.497393 -0.174249
# 10  [{'lat': 51.504662, 'lng': -0.130217, 'label':...  51.504662 -0.130217
# 11  [{'lat': 51.49718901346113, 'lng': -0.17783717...  51.497189 -0.177837
# 12  [{'lat': 51.52557470914815, 'lng': -0.13496745...  51.525575 -0.134967
# 13  [{'lat': 51.52595028538521, 'lng': -0.09666999...  51.525950 -0.096670
# 14  [{'lat': 51.510429, 'lng': -0.12394, 'label': ...  51.510429 -0.123940
# 15  [{'lat': 51.497559070416386, 'lng': -0.1742564...  51.497559 -0.174256
# 16  [{'lat': 51.497265, 'lng': -0.17463294, 'label...  51.497265 -0.174633
# 17  [{'lat': 51.496516643696495, 'lng': -0.1744761...  51.496517 -0.174476
# 18  [{'lat': 51.524409, 'lng': -0.132057, 'label':...  51.524409 -0.132057
# 19  [{'lat': 51.5069938037823, 'lng': -0.146236043...  51.506994 -0.146236
# 20  [{'lat': 51.523705, 'lng': -0.199853, 'label':...  51.523705 -0.199853
# 21  [{'lat': 51.55350923390426, 'lng': -0.11138797...  51.553509 -0.111388
# 22  [{'lat': 51.5138438414177, 'lng': -0.131793022...  51.513844 -0.131793
# 23  [{'lat': 51.514711846369856, 'lng': -0.1306526...  51.514712 -0.130653
# 24  [{'lat': 51.51667965073041, 'lng': -0.15128672...  51.516680 -0.151287
# 25  [{'lat': 51.46491923087138, 'lng': -0.16965409...  51.464919 -0.169654
# 26  [{'lat': 51.50082216506806, 'lng': -0.12434720...  51.500822 -0.124347
# 27  [{'lat': 51.510540527481915, 'lng': -0.1376896...  51.510541 -0.137690
# 28  [{'lat': 51.52926447531897, 'lng': -0.12731944...  51.529264 -0.127319
# 29  [{'lat': 51.512076, 'lng': -0.137109, 'label':...  51.512076 -0.137109
#
#         neighborhood postalCode           state                        id
# 0   South Kensington    SW7 2DD  Greater London  4ac518cdf964a520e9a520e3
# 1                NaN    SE1 9GU  Greater London  54421c23498e3db5fc823d25
# 2                NaN   WC2A 2AE  Greater London  4af1a842f964a520e5e121e3
# 3                NaN   WC1E 6BT  Greater London  4b92941df964a520370634e3
# 4                NaN    SW7 2DD  Greater London  4beb261ff90e9c744480e3ed
# 5                NaN        NaN             NaN  4fa10925e4b0ebb3531a6006
# 6                NaN        SE1  Greater London  5c2f52e475dcb7002c5c86c2
# 7                NaN    W1G 9XU  Greater London  58dbb70883622d650986cc3d
# 8                NaN   WC2A 2HD  Greater London  4b76e42cf964a520ba672ee3
# 9                NaN    SW7 2DD  Greater London  4c5d480e85a1e21ee0ed5811
# 10               NaN        NaN             NaN  53eb0b7a498e7f61e4f5c9ba
# 11               NaN    SW7 2DD  Greater London  4f65fbd5e4b0ce431e84619a
# 12               NaN    NW1 2BE  Greater London  4ee077cce5fa0be346679396
# 13               NaN    W1J 0BA  Greater London  528cc10f11d280a7af225d00
# 14               NaN        NaN             NaN  4c3ef85adb3b1b8ddd146695
# 15               NaN    SW7 2DD  Greater London  51222524e4b08f84c1651d98
# 16               NaN        SW7  Greater London  595f6094f79faa623f5589c3
# 17               NaN        NaN             NaN  523d8e2a11d22f1ce9d27df7
# 18               NaN   WC1E 6BT  Greater London  50ed8259e4b06915b47660f2
# 19               NaN        NaN  Greater London  4ef71d5b0e61a0846d386d49
# 20               NaN        NaN  Greater London  4e5e17ed22718258c488dde8
# 21               NaN     N7 7DD  Greater London  524ebf31498e6881221ca459
# 22               NaN    W1d 4sn  Greater London  4f3813d800398129cba67006
# 23               NaN        NaN             NaN  55683b63498ecc78c0bbffd9
# 24               NaN    W1U 3AJ  Greater London  4add7318f964a520036521e3
# 25               NaN        NaN             NaN  4faa5801e4b0b7e221386f18
# 26               NaN   SW1A 2LW  Greater London  4fa041090cd6294ec9eb478d
# 27               NaN        NaN             NaN  55d461f1498e82e21348ca0a
# 28               NaN        NaN  Greater London  4fbbcebce4b0bc54729473d3
# 29               NaN    W1F 9DJ  Greater London  511cd850e4b005f41de6c9a5

# %%
dataframe_filtered.name
# Out:
# 0                                        Science Museum
# 1                                Science Gallery London
# 2     London School of Economics and Political Scien...
# 3                                   UCL Science Library
# 4                                 Science Museum (IMAX)
# 5                                           Science Lab
# 6                                  Science Gallery Café
# 7                                               Science
# 8                                           LSE Library
# 9                                   Science Museum Shop
# 10                        Royal Parks Office - St James
# 11                     Science Museum Gallery of Flight
# 12                                 Science Media Centre
# 13                                  The Science Council
# 14                                  Audience Science HQ
# 15                            Science Museum Launch Pad
# 16                             Science Museum Live Wire
# 17                   Science Museum Virgin Media Studio
# 18     Department of Science and Technology Studies UCL
# 19                       Third Church Of Christ Science
# 20                                Science Photo Libraru
# 21                                       Science Centre
# 22                                        Media Science
# 23                             Forensic Science Service
# 24                       The School of Economic Science
# 25                                        science class
# 26    Treasure Walks London Royal Palaces and Parks ...
# 27                                  Integral Ad Science
# 28                          Social Science Reading Room
# 29                               Gotham Digital Science
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Science Parks',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
venue_id = '4fa862b3e4b0ebff2f749f06' 
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4fa862b3e4b0ebff2f749f06?client_id=HRYCYRRH44B02GOSP1MNOVC1AVLFQTAIT1ZFSSMIXBAFXF13&client_secret=MGW2M22FVAXDIIQOE42J55BRE0KCCSYLEUHPT3JOBICD55OR&v=20180604'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['pageUpdates', 'likes', 'specials', 'timeZone', 'shortUrl', 'hasMenu', 'ratingColor', 'url', 'dislike', 'rating', 'photos', 'createdAt', 'canonicalUrl', 'bestPhoto', 'contact', 'verified', 'colors', 'listed', 'popular', 'id', 'attributes', 'categories', 'location', 'beenHere', 'hours', 'inbox', 'reasons', 'allowMenuUrlEdit', 'price', 'tips', 'menu', 'ok', 'delivery', 'hereNow', 'name', 'ratingSignals', 'stats'])
# {'allowMenuUrlEdit': True,
#  'attributes': {'groups': [{'count': 1,
#     'items': [{'displayName': 'Price', 'displayValue': '$$', 'priceTier': 2}],
#     'name': 'Price',
#     'summary': '$$',
#     'type': 'price'},
#    {'count': 7,
#     'items': [{'displayName': 'Credit Cards',
#       'displayValue': 'Yes (incl. American Express)'}],
#     'name': 'Credit Cards',
#     'summary': 'Credit Cards',
#     'type': 'payments'},
#    {'count': 1,
#     'items': [{'displayName': 'Outdoor Seating', 'displayValue': 'Yes'}],
#     'name': 'Outdoor Seating',
#     'summary': 'Outdoor Seating',
#     'type': 'outdoorSeating'},
#    {'count': 8,
#     'items': [{'displayName': 'Brunch', 'displayValue': 'Brunch'},
#      {'displayName': 'Lunch', 'displayValue': 'Lunch'},
#      {'displayName': 'Dinner', 'displayValue': 'Dinner'},
#      {'displayName': 'Happy Hour', 'displayValue': 'Happy Hour'}],
#     'name': 'Menus',
#     'summary': 'Happy Hour, Brunch & more',
#     'type': 'serves'},
#    {'count': 5,
#     'items': [{'displayName': 'Beer', 'displayValue': 'Beer'},
#      {'displayName': 'Wine', 'displayValue': 'Wine'},
#      {'displayName': 'Cocktails', 'displayValue': 'Cocktails'}],
#     'name': 'Drinks',
#     'summary': 'Beer, Wine & Cocktails',
#     'type': 'drinks'},
#    {'count': 5,
#     'items': [{'displayName': 'Delivery', 'displayValue': 'Delivery'}],
#     'name': 'Dining Options',
#     'summary': 'Delivery',
#     'type': 'diningOptions'}]},
#  'beenHere': {'count': 0,
#   'lastCheckinExpiredAt': 0,
#   'marked': False,
#   'unconfirmedCount': 0},
#  'bestPhoto': {'createdAt': 1336776717,
#   'height': 640,
#   'id': '4fad980de4b091b4626c3633',
#   'prefix': 'https://fastly.4sqi.net/img/general/',
#   'source': {'name': 'Foursquare for Android',
#    'url': 'https://foursquare.com/download/#/android'},
#   'suffix': '/ya1iQFI7pLjuIJp1PGDKlrZS3OJdHCF7tpILMmjv_2w.jpg',
#   'visibility': 'public',
#   'width': 480},
#  'canonicalUrl': 'https://foursquare.com/v/harrys-italian-pizza-bar/4fa862b3e4b0ebff2f749f06',
#  'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#     'suffix': '.png'},
#    'id': '4bf58dd8d48988d1ca941735',
#    'name': 'Pizza Place',
#    'pluralName': 'Pizza Places',
#    'primary': True,
#    'shortName': 'Pizza'},
#   {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#     'suffix': '.png'},
#    'id': '4bf58dd8d48988d110941735',
#    'name': 'Italian Restaurant',
#    'pluralName': 'Italian Restaurants',
#    'shortName': 'Italian'}],
#  'colors': {'algoVersion': 3,
#   'highlightColor': {'photoId': '4fad980de4b091b4626c3633',
#    'value': -13619152},
#   'highlightTextColor': {'photoId': '4fad980de4b091b4626c3633', 'value': -1}},
#  'contact': {'formattedPhone': '(212) 608-1007', 'phone': '2126081007'},
#  'createdAt': 1336435379,
#  'delivery': {'id': '294544',
#   'provider': {'icon': {'name': '/delivery_provider_seamless_20180129.png',
#     'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#     'sizes': [40, 50]},
#    'name': 'seamless'},
#   'url': 'https://www.seamless.com/menu/harrys-italian-pizza-bar-225-murray-st-new-york/294544?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=294544'},
#  'dislike': False,
#  'hasMenu': True,
#  'hereNow': {'count': 0, 'groups': [], 'summary': 'Nobody here'},
#  'hours': {'dayData': [],
#   'isLocalHoliday': False,
#   'isOpen': False,
#   'richStatus': {'entities': [], 'text': 'Closed until 11:30 AM'},
#   'status': 'Closed until 11:30 AM',
#   'timeframes': [{'days': 'Mon–Wed, Sun',
#     'open': [{'renderedTime': '11:30 AM–11:00 PM'}],
#     'segments': []},
#    {'days': 'Thu–Sat',
#     'includesToday': True,
#     'open': [{'renderedTime': '11:30 AM–Midnight'}],
#     'segments': []}]},
#  'id': '4fa862b3e4b0ebff2f749f06',
#  'inbox': {'count': 0, 'items': []},
#  'likes': {'count': 120,
#   'groups': [{'count': 120, 'items': [], 'type': 'others'}],
#   'summary': '120 Likes'},
#  'listed': {'count': 54,
#   'groups': [{'count': 54,
#     'items': [{'canonicalUrl': 'https://foursquare.com/becca_mcarthur/list/manhattan-haunts',
#       'collaborative': False,
#       'createdAt': 1336094672,
#       'description': '',
#       'editable': False,
#       'followers': {'count': 22},
#       'id': '4fa32fd0e4b04193744746b1',
#       'listItems': {'count': 187,
#        'items': [{'createdAt': 1342934485,
#          'id': 'v4fa862b3e4b0ebff2f749f06'}]},
#       'name': 'Manhattan Haunts',
#       'photo': {'createdAt': 1317849414,
#        'height': 330,
#        'id': '4e8cc9461081e3b3544e12e5',
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/0NLVU2HC1JF4DXIMKWUFW3QBUT31DC11EFNYYHMJG3NDWAPS.jpg',
#        'user': {'firstName': 'Time Out New York',
#         'gender': 'none',
#         'id': '742542',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/XXHKCBSQHBORZNSR.jpg'},
#         'type': 'page'},
#        'visibility': 'public',
#        'width': 492},
#       'public': True,
#       'type': 'others',
#       'updatedAt': 1380845377,
#       'url': '/becca_mcarthur/list/manhattan-haunts',
#       'user': {'firstName': 'Becca',
#        'gender': 'female',
#        'id': '24592223',
#        'lastName': 'M',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/24592223-RAW2UYM0GIB1U40K.jpg'}}},
#      {'canonicalUrl': 'https://foursquare.com/kinosfault/list/usa-nyc-man-fidi',
#       'collaborative': False,
#       'createdAt': 1336836475,
#       'description': 'Where to go for decent eats in the restaurant wasteland of Downtown NYC aka FiDi, along with Tribeca & Battery Park City.',
#       'editable': False,
#       'followers': {'count': 20},
#       'id': '4fae817be4b085f6b2a74d19',
#       'listItems': {'count': 273,
#        'items': [{'createdAt': 1373909433,
#          'id': 'v4fa862b3e4b0ebff2f749f06'}]},
#       'name': 'USA NYC MAN FiDi',
#       'photo': {'createdAt': 1436043666,
#        'height': 960,
#        'id': '55984992498e13ba75e353bb',
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/12113441_iOa6Uh-Xi8bhj2-gpzkkw8MKiAIs7RmOcz_RM7m8ink.jpg',
#        'user': {'firstName': 'Kino',
#         'gender': 'male',
#         'id': '12113441',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/12113441-K5HTHFLU2MUCM0CM.jpg'}},
#        'visibility': 'public',
#        'width': 540},
#       'public': True,
#       'type': 'others',
#       'updatedAt': 1556754919,
#       'url': '/kinosfault/list/usa-nyc-man-fidi',
#       'user': {'firstName': 'Kino',
#        'gender': 'male',
#        'id': '12113441',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/12113441-K5HTHFLU2MUCM0CM.jpg'}}},
#      {'canonicalUrl': 'https://foursquare.com/rickr7/list/nyc-resturants',
#       'collaborative': True,
#       'createdAt': 1339944944,
#       'description': '',
#       'editable': False,
#       'followers': {'count': 12},
#       'id': '4fddeff0e4b0e078037ac0d3',
#       'listItems': {'count': 195,
#        'items': [{'createdAt': 1514680908,
#          'id': 't54ed3b13498e857fd7dbb6fc'}]},
#       'name': 'NYC Resturants',
#       'photo': {'createdAt': 1349704979,
#        'height': 800,
#        'id': '5072dd13e4b09145cdf782d1',
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/208205_fGh2OuAZ9qJ4agbAA5wMVNOSIm9kNUlRtNwj1N-adqg.jpg',
#        'user': {'firstName': 'Thalia',
#         'gender': 'female',
#         'id': '208205',
#         'lastName': 'K',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/SNOOLCAW2AG04ZKD.jpg'}},
#        'visibility': 'public',
#        'width': 800},
#       'public': True,
#       'type': 'others',
#       'updatedAt': 1559554908,
#       'url': '/rickr7/list/nyc-resturants',
#       'user': {'firstName': 'Richard',
#        'gender': 'male',
#        'id': '21563126',
#        'lastName': 'R',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/21563126_v05J1KPw_SVj6Ehq9g8B9jeAGjFUMsU5QGl-NZ8inUQ7pKQm5bKplW37EmR7jS2A7GYPBBAtl.jpg'}}},
#      {'canonicalUrl': 'https://foursquare.com/sweetiewill/list/foodie-love-in-ny--02',
#       'collaborative': False,
#       'createdAt': 1382467210,
#       'description': '',
#       'editable': False,
#       'followers': {'count': 7},
#       'id': '5266c68a498e7c667807fe09',
#       'listItems': {'count': 200,
#        'items': [{'createdAt': 1386809936,
#          'id': 'v4fa862b3e4b0ebff2f749f06'}]},
#       'name': 'Foodie Love in NY - 02',
#       'public': True,
#       'type': 'others',
#       'updatedAt': 1391995585,
#       'url': '/sweetiewill/list/foodie-love-in-ny--02',
#       'user': {'firstName': 'WiLL',
#        'gender': 'male',
#        'id': '547977',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/-Q5NYGDMFDMOITQRR.jpg'}}}],
#     'name': 'Lists from other people',
#     'type': 'others'}]},
#  'location': {'address': '225 Murray St',
#   'cc': 'US',
#   'city': 'New York',
#   'country': 'United States',
#   'formattedAddress': ['225 Murray St', 'New York, NY 10282', 'United States'],
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 40.71521779064671,
#     'lng': -74.01473940209351}],
#   'lat': 40.71521779064671,
#   'lng': -74.01473940209351,
#   'postalCode': '10282',
#   'state': 'NY'},
#  'menu': {'anchor': 'View Menu',
#   'label': 'Menu',
#   'mobileUrl': 'https://foursquare.com/v/4fa862b3e4b0ebff2f749f06/device_menu',
#   'type': 'Menu',
#   'url': 'https://foursquare.com/v/harrys-italian-pizza-bar/4fa862b3e4b0ebff2f749f06/menu'},
#  'name': "Harry's Italian Pizza Bar",
#  'ok': False,
#  'pageUpdates': {'count': 0, 'items': []},
#  'photos': {'count': 149,
#   'groups': [{'count': 0,
#     'items': [],
#     'name': "Friends' check-in photos",
#     'type': 'checkin'},
#    {'count': 149,
#     'items': [{'createdAt': 1336776717,
#       'height': 640,
#       'id': '4fad980de4b091b4626c3633',
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'source': {'name': 'Foursquare for Android',
#        'url': 'https://foursquare.com/download/#/android'},
#       'suffix': '/ya1iQFI7pLjuIJp1PGDKlrZS3OJdHCF7tpILMmjv_2w.jpg',
#       'user': {'firstName': 'Leony',
#        'gender': 'none',
#        'id': '13676709',
#        'lastName': 'N',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/T0ANFNGNMCHUDEUE.jpg'}},
#       'visibility': 'public',
#       'width': 480}],
#     'name': 'Venue photos',
#     'type': 'venue'}],
#   'summary': '0 photos'},
#  'popular': {'isLocalHoliday': False,
#   'isOpen': False,
#   'timeframes': [{'days': 'Today',
#     'includesToday': True,
#     'open': [{'renderedTime': 'Noon–11:00 PM'}],
#     'segments': []},
#    {'days': 'Sun',
#     'open': [{'renderedTime': 'Noon–3:00 PM'},
#      {'renderedTime': '5:00 PM–8:00 PM'}],
#     'segments': []},
#    {'days': 'Mon',
#     'open': [{'renderedTime': 'Noon–2:00 PM'},
#      {'renderedTime': '6:00 PM–8:00 PM'}],
#     'segments': []},
#    {'days': 'Tue–Thu',
#     'open': [{'renderedTime': 'Noon–2:00 PM'},
#      {'renderedTime': '5:00 PM–10:00 PM'}],
#     'segments': []},
#    {'days': 'Fri',
#     'open': [{'renderedTime': 'Noon–3:00 PM'},
#      {'renderedTime': '5:00 PM–11:00 PM'}],
#     'segments': []}]},
#  'price': {'currency': '$', 'message': 'Moderate', 'tier': 2},
#  'rating': 7.1,
#  'ratingColor': 'C5DE35',
#  'ratingSignals': 214,
#  'reasons': {'count': 1,
#   'items': [{'reasonName': 'rawLikesReason',
#     'summary': 'Lots of people like this place',
#     'type': 'general'}]},
#  'shortUrl': 'http://4sq.com/JNblHV',
#  'specials': {'count': 0, 'items': []},
#  'stats': {'tipCount': 57},
#  'timeZone': 'America/New_York',
#  'tips': {'count': 57,
#   'groups': [{'count': 57,
#     'items': [{'agreeCount': 4,
#       'canonicalUrl': 'https://foursquare.com/item/53d27909498e0523841340b6',
#       'createdAt': 1406302473,
#       'disagreeCount': 0,
#       'id': '53d27909498e0523841340b6',
#       'lang': 'en',
#       'likes': {'count': 4,
#        'groups': [{'count': 4,
#          'items': [{'firstName': 'P.',
#            'gender': 'male',
#            'id': '369426',
#            'lastName': 'M',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/JPQYUWJKUT0H2OO4.jpg'}},
#           {'firstName': 'Diane',
#            'gender': 'female',
#            'id': '87587879',
#            'lastName': 'D',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/87587879-ESLRSZLQ2CBE2P4W.jpg'}},
#           {'firstName': 'Tim',
#            'gender': 'male',
#            'id': '87591341',
#            'lastName': 'S',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/-Z4YK4VKE0JSVXIY1.jpg'}},
#           {'firstName': 'TenantKing.com',
#            'gender': 'none',
#            'id': '87473404',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/87473404-HI5DTBTK0HX401CA.png'},
#            'type': 'page'}],
#          'type': 'others'}],
#        'summary': '4 likes'},
#       'logView': True,
#       'text': "Harry's Italian Pizza bar is known for it's amazing pizza, but did you know that the brunches here are amazing too? Try the Nutella French toast and we know you'll be sold.",
#       'todo': {'count': 0},
#       'type': 'user',
#       'user': {'firstName': 'TenantKing.com',
#        'gender': 'none',
#        'id': '87473404',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/87473404-HI5DTBTK0HX401CA.png'},
#        'type': 'page'}}],
#     'name': 'All tips',
#     'type': 'others'}]},
#  'url': 'http://harrysitalian.com',
#  'verified': False}

# %%
## Ecco Tips
limit = 15 # set limit to be greater than or equal to the total number of tips
url = 'https://api.foursquare.com/v2/venues/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION, limit)

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d189074e8f92800235e1c14'},
#  'response': {'tips': {'count': 57,
#    'items': [{'agreeCount': 1,
#      'canonicalUrl': 'https://foursquare.com/item/513b95ade4b0ef9359ef0cda',
#      'createdAt': 1362859437,
#      'disagreeCount': 0,
#      'id': '513b95ade4b0ef9359ef0cda',
#      'lang': 'en',
#      'likes': {'count': 1,
#       'groups': [{'count': 1,
#         'items': [{'firstName': 'Kailey',
#           'gender': 'female',
#           'id': '1802920',
#           'lastName': 'M',
#           'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#            'suffix': '/FSCOBUBEIHNEIGCP.jpg'}}],
#         'type': 'others'}],
#       'summary': '1 like'},
#      'logView': True,
#      'text': 'Great spot! Has a legit bar with a ton of flat screens and plenty of room for drinking, socializing and pizza eating. The food is great. A must go in Financial District!',
#      'todo': {'count': 0},
#      'type': 'user',
#      'user': {'firstName': 'Heather',
#       'gender': 'female',
#       'id': '6343050',
#       'lastName': 'C',
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/CMRXTUXQAIZBQQEX.jpg'}}}]}}}

# %%
tips = results['response']['tips']['items']

tip = results['response']['tips']['items'][0]
tip.keys()
# Out:
# dict_keys(['user', 'todo', 'type', 'createdAt', 'logView', 'disagreeCount', 'text', 'lang', 'canonicalUrl', 'agreeCount', 'id', 'likes'])

# %%
user_id = '484542633' # user ID with most agree counts and complete profile

url = 'https://api.foursquare.com/v2/users/{}?client_id={}&client_secret={}&v={}'.format(user_id, CLIENT_ID, CLIENT_SECRET, VERSION) # define URL

# send GET request
results = requests.get(url).json()
user_data = results['response']['user']

# display features associated with user
user_data.keys()
# Out:
# dict_keys(['firstName', 'mayorships', 'friends', 'type', 'bio', 'photo', 'checkins', 'tips', 'homeCity', 'canonicalUrl', 'lenses', 'gender', 'photos', 'contact', 'lastName', 'id', 'lists'])

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Ecco


# add Ecco as a red circle mark
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    popup='Ecco',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(venues_map)


# add popular spots to the map as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# define URL
url = 'https://api.foursquare.com/v2/venues/trending?client_id={}&client_secret={}&ll={},{}&v={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION)

# send GET request and get trending venues
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d189087342adf0038d86809'},
#  'response': {'venues': []}}

# %%
if len(results['response']['venues']) == 0:
    trending_venues_df = 'No trending venues are available at the moment!'
    
else:
    trending_venues = results['response']['venues']
    trending_venues_df = json_normalize(trending_venues)

    # filter columns
    columns_filtered = ['name', 'categories'] + ['location.distance', 'location.city', 'location.postalCode', 'location.state', 'location.country', 'location.lat', 'location.lng']
    trending_venues_df = trending_venues_df.loc[:, columns_filtered]

    # filter the category for each row
    trending_venues_df['categories'] = trending_venues_df.apply(get_category_type, axis=1)

# %%
trending_venues_df
# Out:
# 'No trending venues are available at the moment!'

# %%
if len(results['response']['venues']) == 0:
    venues_map = 'Cannot generate visual as no trending venues are available at the moment!'

else:
    venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Ecco


    # add Ecco as a red circle mark
    folium.features.CircleMarker(
        [latitude, longitude],
        radius=10,
        popup='Ecco',
        fill=True,
        color='red',
        fill_color='red',
        fill_opacity=0.6
    ).add_to(venues_map)


    # add the trending venues as blue circle markers
    for lat, lng, label in zip(trending_venues_df['location.lat'], trending_venues_df['location.lng'], trending_venues_df['name']):
        folium.features.CircleMarker(
            [lat, lng],
            radius=5,
            poup=label,
            fill=True,
            color='blue',
            fill_color='blue',
            fill_opacity=0.6
        ).add_to(venues_map)

# %%
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
