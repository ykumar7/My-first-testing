# %%
### Import necessary Libraries

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/DSX-Python35
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     certifi-2018.8.24          |        py35_1001         139 KB  conda-forge
#     geographiclib-1.49         |             py_0          32 KB  conda-forge
#     ca-certificates-2019.6.16  |       hecc5488_0         145 KB  conda-forge
#     openssl-1.0.2r             |       h14c3975_0         3.1 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.49-py_0         conda-forge
#     geopy:           1.20.0-py_0       conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.1.23-0                   --> 2019.6.16-hecc5488_0 conda-forge
#     certifi:         2018.8.24-py35_1              --> 2018.8.24-py35_1001  conda-forge
#
# The following packages will be DOWNGRADED:
#
#     openssl:         1.0.2s-h7b6447c_0             --> 1.0.2r-h14c3975_0    conda-forge
#
#
# Downloading and Extracting Packages
# geopy-1.20.0         | 57 KB     | ##################################### | 100%
# certifi-2018.8.24    | 139 KB    | ##################################### | 100%
# geographiclib-1.49   | 32 KB     | ##################################### | 100%
# ca-certificates-2019 | 145 KB    | ##################################### | 100%
# openssl-1.0.2r       | 3.1 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/DSX-Python35
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     altair-2.2.2               |           py35_1         462 KB  conda-forge
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         560 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  2.2.2-py35_1 conda-forge
#     branca:  0.3.1-py_0   conda-forge
#     folium:  0.5.0-py_0   conda-forge
#     vincent: 0.4.4-py_1   conda-forge
#
#
# Downloading and Extracting Packages
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# altair-2.2.2         | 462 KB    | ##################################### | 100%
# branca-0.3.1         | 25 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = 'HRYCYRRH44B02GOSP1MNOVC1AVLFQTAIT1ZFSSMIXBAFXF13' # your Foursquare ID
CLIENT_SECRET = 'MGW2M22FVAXDIIQOE42J55BRE0KCCSYLEUHPT3JOBICD55OR' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: HRYCYRRH44B02GOSP1MNOVC1AVLFQTAIT1ZFSSMIXBAFXF13
# CLIENT_SECRET:MGW2M22FVAXDIIQOE42J55BRE0KCCSYLEUHPT3JOBICD55OR

# %%
address = 'London'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 51.5073219 -0.1276474

# %%
latitude = 51.5073219
longitude = -0.1276474

# %%
search_query = 'STP'
radius = 5000
print(search_query + ' .... OK!')
# Out:
# STP .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=HRYCYRRH44B02GOSP1MNOVC1AVLFQTAIT1ZFSSMIXBAFXF13&client_secret=MGW2M22FVAXDIIQOE42J55BRE0KCCSYLEUHPT3JOBICD55OR&ll=51.5073219,-0.1276474&v=20180604&query=STP&radius=5000&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d1675ff6bdee6002c054e23'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/trainstation_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d129951735',
#       'name': 'Train Station',
#       'pluralName': 'Train Stations',
#       'primary': True,
#       'shortName': 'Train Station'}],
#     'hasPerk': False,
#     'id': '4ac518f7f964a520c6af20e3',
#     'location': {'address': 'Pancras Rd',
#      'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'crossStreet': 'Euston Rd',
#      'distance': 2726,
#      'formattedAddress': ['Pancras Rd (Euston Rd)',
#       'London',
#       'Greater London',
#       'NW1 2QP',
#       'United Kingdom'],
#      'lat': 51.531796676193856,
#      'lng': -0.12615392657628297,
#      'postalCode': 'NW1 2QP',
#      'state': 'Greater London'},
#     'name': 'London St Pancras International Railway Station (STP) (London St Pancras International Railway Station)',
#     'referralId': 'v-1561753087'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/trainstation_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d129951735',
#       'name': 'Train Station',
#       'pluralName': 'Train Stations',
#       'primary': True,
#       'shortName': 'Train Station'}],
#     'hasPerk': False,
#     'id': '4bcc08273740b7139c756365',
#     'location': {'address': 'Pancras Rd',
#      'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'distance': 2714,
#      'formattedAddress': ['Pancras Rd',
#       'London',
#       'Greater London',
#       'NW1 2QP',
#       'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.53168808977662,
#        'lng': -0.12613641845489332}],
#      'lat': 51.53168808977662,
#      'lng': -0.12613641845489332,
#      'neighborhood': 'Kings Cross',
#      'postalCode': 'NW1 2QP',
#      'state': 'Greater London'},
#     'name': 'London St Pancras Eurostar Terminal (London St Pancras International Eurostar Terminal)',
#     'referralId': 'v-1561753087'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/trainstation_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d129951735',
#       'name': 'Train Station',
#       'pluralName': 'Train Stations',
#       'primary': True,
#       'shortName': 'Train Station'}],
#     'hasPerk': False,
#     'id': '4e40f13dc65b4f2fdeb09bf0',
#     'location': {'address': 'St Pancras East Midland',
#      'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'distance': 2729,
#      'formattedAddress': ['St Pancras East Midland',
#       'London',
#       'Greater London',
#       'NW1 2QP',
#       'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.531838612994704,
#        'lng': -0.1269311779469517}],
#      'lat': 51.531838612994704,
#      'lng': -0.1269311779469517,
#      'postalCode': 'NW1 2QP',
#      'state': 'Greater London'},
#     'name': 'St Pancras International Station (STP) — East Midlands',
#     'referralId': 'v-1561753087'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/trainstation_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d129951735',
#       'name': 'Train Station',
#       'pluralName': 'Train Stations',
#       'primary': True,
#       'shortName': 'Train Station'}],
#     'hasPerk': False,
#     'id': '54d37e52498ef9e0d404d534',
#     'location': {'address': 'Midland Road',
#      'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'distance': 2723,
#      'formattedAddress': ['Midland Road',
#       'London',
#       'Greater London',
#       'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.53178652158595,
#        'lng': -0.12701034540076928}],
#      'lat': 51.53178652158595,
#      'lng': -0.12701034540076928,
#      'state': 'Greater London'},
#     'name': 'St Pancras International Station (STP) — Thameslink',
#     'referralId': 'v-1561753087'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/trainstation_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d129951735',
#       'name': 'Train Station',
#       'pluralName': 'Train Stations',
#       'primary': True,
#       'shortName': 'Train Station'}],
#     'hasPerk': False,
#     'id': '4f9a9abbe4b01da4fec13fa8',
#     'location': {'address': 'St Pancras International Station',
#      'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'crossStreet': 'Platforms 11-13',
#      'distance': 2824,
#      'formattedAddress': ['St Pancras International Station (Platforms 11-13)',
#       'London',
#       'Greater London',
#       'NW1 2QP',
#       'United Kingdom'],
#      'lat': 51.53268505521353,
#      'lng': -0.12654868361446384,
#      'postalCode': 'NW1 2QP',
#      'state': 'Greater London'},
#     'name': 'St Pancras International Station (STP) — Southeastern HighSpeed',
#     'referralId': 'v-1561753087'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'primary': True,
#       'shortName': 'Church'}],
#     'hasPerk': False,
#     'id': '4ac518cef964a520f5a520e3',
#     'location': {'address': "St Paul's Church Yard",
#      'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'distance': 2151,
#      'formattedAddress': ["St Paul's Church Yard",
#       'London',
#       'Greater London',
#       'EC4M 8AD',
#       'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.51387722554811,
#        'lng': -0.09842634201049805}],
#      'lat': 51.51387722554811,
#      'lng': -0.09842634201049805,
#      'postalCode': 'EC4M 8AD',
#      'state': 'Greater London'},
#     'name': "St Paul's Cathedral",
#     'referralId': 'v-1561753087'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/garden_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d15a941735',
#       'name': 'Garden',
#       'pluralName': 'Gardens',
#       'primary': True,
#       'shortName': 'Garden'}],
#     'hasPerk': False,
#     'id': '55573a8c498eee8cd56fa2db',
#     'location': {'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'distance': 534,
#      'formattedAddress': ['London', 'Greater London', 'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.511657,
#        'lng': -0.124331}],
#      'lat': 51.511657,
#      'lng': -0.124331,
#      'state': 'Greater London'},
#     'name': "St. Paul's Church Churchyard",
#     'referralId': 'v-1561753087'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/subway_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1fd931735',
#       'name': 'Metro Station',
#       'pluralName': 'Metro Stations',
#       'primary': True,
#       'shortName': 'Metro'}],
#     'hasPerk': False,
#     'id': '4acf786af964a520e6d320e3',
#     'location': {'address': 'Euston Rd',
#      'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'distance': 2611,
#      'formattedAddress': ['Euston Rd',
#       'London',
#       'Greater London',
#       'N1 9AL',
#       'United Kingdom'],
#      'lat': 51.530690890052085,
#      'lng': -0.12427857349132986,
#      'postalCode': 'N1 9AL',
#      'state': 'Greater London'},
#     'name': "King's Cross St. Pancras London Underground Station",
#     'referralId': 'v-1561753087'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'primary': True,
#       'shortName': 'Church'}],
#     'hasPerk': False,
#     'id': '4b2e5b98f964a520c5de24e3',
#     'location': {'address': 'Bedford St',
#      'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'distance': 511,
#      'formattedAddress': ['Bedford St',
#       'London',
#       'Greater London',
#       'WC2E 9ED',
#       'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.511388712882706,
#        'lng': -0.12420153436210384}],
#      'lat': 51.511388712882706,
#      'lng': -0.12420153436210384,
#      'postalCode': 'WC2E 9ED',
#      'state': 'Greater London'},
#     'name': "St. Paul's Church",
#     'referralId': 'v-1561753087'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'primary': True,
#       'shortName': 'Hotel'}],
#     'hasPerk': False,
#     'id': '4d00c69af1605481dce59fea',
#     'location': {'address': 'Euston Rd',
#      'cc': 'GB',
#      'city': "King's Cross",
#      'country': 'United Kingdom',
#      'distance': 2494,
#      'formattedAddress': ['Euston Rd',
#       "King's Cross",
#       'Greater London',
#       'NW1 2AR',
#       'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.5296995,
#        'lng': -0.1258865}],
#      'lat': 51.5296995,
#      'lng': -0.1258865,
#      'postalCode': 'NW1 2AR',
#      'state': 'Greater London'},
#     'name': 'St. Pancras Renaissance Hotel London',
#     'referralId': 'v-1561753087',
#     'venuePage': {'id': '129932654'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/subway_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1fd931735',
#       'name': 'Metro Station',
#       'pluralName': 'Metro Stations',
#       'primary': True,
#       'shortName': 'Metro'}],
#     'hasPerk': False,
#     'id': '4adc7ef3f964a520b12c21e3',
#     'location': {'address': '1 Cheapside',
#      'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'crossStreet': 'at Newgate St',
#      'distance': 2266,
#      'formattedAddress': ['1 Cheapside (at Newgate St)',
#       'London',
#       'Greater London',
#       'EC2V 6AA',
#       'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.51502318754615,
#        'lng': -0.09736137848620856}],
#      'lat': 51.51502318754615,
#      'lng': -0.09736137848620856,
#      'postalCode': 'EC2V 6AA',
#      'state': 'Greater London'},
#     'name': "St. Paul's London Underground Station",
#     'referralId': 'v-1561753087'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'primary': True,
#       'shortName': 'Hotel'}],
#     'hasPerk': False,
#     'id': '4bcf48860ffdce72bb58b2c0',
#     'location': {'address': '10 Godliman St',
#      'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'distance': 2055,
#      'formattedAddress': ['10 Godliman St',
#       'London',
#       'Greater London',
#       'EC4V 5AJ',
#       'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.51279862863417,
#        'lng': -0.09932142331450669}],
#      'lat': 51.51279862863417,
#      'lng': -0.09932142331450669,
#      'postalCode': 'EC4V 5AJ',
#      'state': 'Greater London'},
#     'name': 'Grange St. Pauls Hotel',
#     'referralId': 'v-1561753087'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d114951735',
#       'name': 'Bookstore',
#       'pluralName': 'Bookstores',
#       'primary': True,
#       'shortName': 'Bookstore'}],
#     'hasPerk': False,
#     'id': '4dec2a648130115d6be0c45a',
#     'location': {'address': 'Morpeth Terrace',
#      'cc': 'GB',
#      'city': 'Victoria',
#      'country': 'United Kingdom',
#      'distance': 1544,
#      'formattedAddress': ['Morpeth Terrace',
#       'Victoria',
#       'Greater London',
#       'SW1P 1EP',
#       'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.49593630311686,
#        'lng': -0.1403911566950335}],
#      'lat': 51.49593630311686,
#      'lng': -0.1403911566950335,
#      'postalCode': 'SW1P 1EP',
#      'state': 'Greater London'},
#     'name': 'St Pauls Bookshop',
#     'referralId': 'v-1561753087'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'primary': True,
#       'shortName': 'Church'}],
#     'hasPerk': False,
#     'id': '4df7693218a8a7a74302c1ab',
#     'location': {'address': '21A Soho Sq',
#      'cc': 'GB',
#      'city': 'Soho',
#      'country': 'United Kingdom',
#      'crossStreet': 'Sutton Row',
#      'distance': 944,
#      'formattedAddress': ['21A Soho Sq (Sutton Row)',
#       'Soho',
#       'Greater London',
#       'W1D 4NR',
#       'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.51550045469365,
#        'lng': -0.13126692199737008}],
#      'lat': 51.51550045469365,
#      'lng': -0.13126692199737008,
#      'postalCode': 'W1D 4NR',
#      'state': 'Greater London'},
#     'name': "St Patrick's Church",
#     'referralId': 'v-1561753087'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d137941735',
#       'name': 'Theater',
#       'pluralName': 'Theaters',
#       'primary': True,
#       'shortName': 'Theater'}],
#     'hasPerk': False,
#     'id': '558f0381498e1a92146e497b',
#     'location': {'cc': 'GB',
#      'country': 'United Kingdom',
#      'distance': 542,
#      'formattedAddress': ['United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.511495,
#        'lng': -0.123597}],
#      'lat': 51.511495,
#      'lng': -0.123597},
#     'name': "Iris Theatre @ St. Paul's",
#     'referralId': 'v-1561753087'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/eventspace_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d171941735',
#       'name': 'Event Space',
#       'pluralName': 'Event Spaces',
#       'primary': True,
#       'shortName': 'Event Space'}],
#     'hasPerk': False,
#     'id': '4cd6ce63fb595481fbfae550',
#     'location': {'address': 'Royal Festival Hall',
#      'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'crossStreet': 'Southbank Centre',
#      'distance': 780,
#      'formattedAddress': ['Royal Festival Hall (Southbank Centre)',
#       'London',
#       'Greater London',
#       'SE1 8XX',
#       'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.506041789223055,
#        'lng': -0.11657089658569515}],
#      'lat': 51.506041789223055,
#      'lng': -0.11657089658569515,
#      'postalCode': 'SE1 8XX',
#      'state': 'Greater London'},
#     'name': "St Paul's and Weston Roof Pavilions",
#     'referralId': 'v-1561753087'},
#    {'categories': [],
#     'hasPerk': False,
#     'id': '4b964e12f964a52004c534e3',
#     'location': {'address': 'Sheffield St.',
#      'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'crossStreet': 'Portugal St.',
#      'distance': 1141,
#      'formattedAddress': ['Sheffield St. (Portugal St.)',
#       'London',
#       'Greater London',
#       'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.51381972126996,
#        'lng': -0.1148969861587}],
#      'lat': 51.51381972126996,
#      'lng': -0.1148969861587,
#      'state': 'Greater London'},
#     'name': 'St. Philips Medical Centre',
#     'referralId': 'v-1561753087'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'primary': True,
#       'shortName': 'Church'}],
#     'hasPerk': False,
#     'id': '4ac518d2f964a52017a720e3',
#     'location': {'address': 'Euston Rd.',
#      'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'distance': 2205,
#      'formattedAddress': ['Euston Rd.',
#       'London',
#       'Greater London',
#       'NW1 2BA',
#       'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.52706204361282,
#        'lng': -0.13033390045166016}],
#      'lat': 51.52706204361282,
#      'lng': -0.13033390045166016,
#      'postalCode': 'NW1 2BA',
#      'state': 'Greater London'},
#     'name': 'St Pancras Church',
#     'referralId': 'v-1561753087'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'primary': True,
#       'shortName': 'Hotel'}],
#     'hasPerk': False,
#     'id': '4b58e941f964a5205f7228e3',
#     'location': {'address': '24 Ludgate Hill',
#      'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'distance': 1979,
#      'formattedAddress': ['24 Ludgate Hill',
#       'London',
#       'Greater London',
#       'EC4M 7DR',
#       'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.51388221380029,
#        'lng': -0.10109517187523928}],
#      'lat': 51.51388221380029,
#      'lng': -0.10109517187523928,
#      'postalCode': 'EC4M 7DR',
#      'state': 'Greater London'},
#     'name': "Club Quarters Hotel, St. Paul's",
#     'referralId': 'v-1561753087'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/neighborhood_',
#        'suffix': '.png'},
#       'id': '4f2a25ac4b909258e854f55f',
#       'name': 'Neighborhood',
#       'pluralName': 'Neighborhoods',
#       'primary': True,
#       'shortName': 'Neighborhood'}],
#     'hasPerk': False,
#     'id': '5314f6ede4b0e72a36e15ce8',
#     'location': {'cc': 'GB',
#      'country': 'United Kingdom',
#      'distance': 995,
#      'formattedAddress': ['United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.505834428653245,
#        'lng': -0.14180779206917965}],
#      'lat': 51.505834428653245,
#      'lng': -0.14180779206917965},
#     'name': 'St. Pancras',
#     'referralId': 'v-1561753087'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'primary': True,
#       'shortName': 'Art Gallery'}],
#     'hasPerk': False,
#     'id': '511005afe4b04c8cb83038a9',
#     'location': {'cc': 'GB',
#      'country': 'United Kingdom',
#      'distance': 1037,
#      'formattedAddress': ['United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.5105053183169,
#        'lng': -0.1417166542392497}],
#      'lat': 51.5105053183169,
#      'lng': -0.1417166542392497},
#     'name': 'St Petersburg Gallery',
#     'referralId': 'v-1561753087'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'primary': True,
#       'shortName': 'Church'}],
#     'hasPerk': False,
#     'id': '4ef7133d77c8e88f47777cad',
#     'location': {'address': 'Vere Street',
#      'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'distance': 1630,
#      'formattedAddress': ['Vere Street',
#       'London',
#       'Greater London',
#       'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.51547725933961,
#        'lng': -0.14719478959337845}],
#      'lat': 51.51547725933961,
#      'lng': -0.14719478959337845,
#      'state': 'Greater London'},
#     'name': "St. Peter's Church",
#     'referralId': 'v-1561753087'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'primary': True,
#       'shortName': 'Church'}],
#     'hasPerk': False,
#     'id': '4c9614066b35a14356862adc',
#     'location': {'address': 'St Pancras Way',
#      'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'distance': 3078,
#      'formattedAddress': ['St Pancras Way',
#       'London',
#       'Greater London',
#       'NW1 1UL',
#       'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.53492363232326,
#        'lng': -0.1302813727619847}],
#      'lat': 51.53492363232326,
#      'lng': -0.1302813727619847,
#      'postalCode': 'NW1 1UL',
#      'state': 'Greater London'},
#     'name': 'St Pancras Old Church',
#     'referralId': 'v-1561753087'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d143941735',
#       'name': 'Breakfast Spot',
#       'pluralName': 'Breakfast Spots',
#       'primary': True,
#       'shortName': 'Breakfast'}],
#     'hasPerk': False,
#     'id': '4f2bc533e4b0e6b07078e4c2',
#     'location': {'address': 'Great Chapel Street',
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'distance': 1019,
#      'formattedAddress': ['Great Chapel Street', 'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.51550295006862,
#        'lng': -0.13427427351518226}],
#      'lat': 51.51550295006862,
#      'lng': -0.13427427351518226},
#     'name': 'St Patricks Canteen',
#     'referralId': 'v-1561753087'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'primary': True,
#       'shortName': 'Park'}],
#     'hasPerk': False,
#     'id': '4d8f77893bfef04d3225af86',
#     'location': {'address': "St. Paul's Churchyard",
#      'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'distance': 2218,
#      'formattedAddress': ["St. Paul's Churchyard",
#       'London',
#       'Greater London',
#       'E C4M',
#       'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.513449906831404,
#        'lng': -0.09717106819152832}],
#      'lat': 51.513449906831404,
#      'lng': -0.09717106819152832,
#      'postalCode': 'E C4M',
#      'state': 'Greater London'},
#     'name': "St Paul's Churchyard",
#     'referralId': 'v-1561753087'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/historicsite_',
#        'suffix': '.png'},
#       'id': '4deefb944765f83613cdba6e',
#       'name': 'Historic Site',
#       'pluralName': 'Historic Sites',
#       'primary': True,
#       'shortName': 'Historic Site'}],
#     'hasPerk': False,
#     'id': '5c865b31cbcdee002c34265f',
#     'location': {'address': "St Paul's Church Yard",
#      'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'distance': 2164,
#      'formattedAddress': ["St Paul's Church Yard",
#       'London',
#       'Greater London',
#       'E C4M',
#       'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.51386387189887,
#        'lng': -0.09823322296142578}],
#      'lat': 51.51386387189887,
#      'lng': -0.09823322296142578,
#      'postalCode': 'E C4M',
#      'state': 'Greater London'},
#     'name': "St Paul's Crypt",
#     'referralId': 'v-1561753087'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'primary': True,
#       'shortName': 'Hotel'}],
#     'hasPerk': False,
#     'id': '5010104be4b0c9392207fb78',
#     'location': {'address': '100-110 Euston Rd',
#      'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'distance': 2360,
#      'formattedAddress': ['100-110 Euston Rd',
#       'London',
#       'Greater London',
#       'NW1 2AJ',
#       'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.528521278066805,
#        'lng': -0.12816088294108588}],
#      'lat': 51.528521278066805,
#      'lng': -0.12816088294108588,
#      'postalCode': 'NW1 2AJ',
#      'state': 'Greater London'},
#     'name': 'Pullman London St Pancras',
#     'referralId': 'v-1561753087'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'primary': True,
#       'shortName': 'Church'}],
#     'hasPerk': False,
#     'id': '4b07a934f964a52046ff22e3',
#     'location': {'address': 'Wilton St',
#      'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'distance': 1798,
#      'formattedAddress': ['Wilton St',
#       'London',
#       'Greater London',
#       'SW1 X 8',
#       'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.49785380588896,
#        'lng': -0.14867284600182398}],
#      'lat': 51.49785380588896,
#      'lng': -0.14867284600182398,
#      'postalCode': 'SW1 X 8',
#      'state': 'Greater London'},
#     'name': "St Peter's Eaton Sq",
#     'referralId': 'v-1561753087'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'primary': True,
#       'shortName': 'Church'}],
#     'hasPerk': False,
#     'id': '4d12331f804a2d43abc192e3',
#     'location': {'address': '136 Clerkenwell Rd',
#      'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'distance': 2101,
#      'formattedAddress': ['136 Clerkenwell Rd',
#       'London',
#       'Greater London',
#       'EC1R 5DL',
#       'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.52220283972082,
#        'lng': -0.1089828940812208}],
#      'lat': 51.52220283972082,
#      'lng': -0.1089828940812208,
#      'postalCode': 'EC1R 5DL',
#      'state': 'Greater London'},
#     'name': "St Peter's Italian Church",
#     'referralId': 'v-1561753087'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'primary': True,
#       'shortName': 'Hotel'}],
#     'hasPerk': False,
#     'id': '5423bcda498e0eae829271c6',
#     'location': {'address': '88 Euston Rd',
#      'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'distance': 2378,
#      'formattedAddress': ['88 Euston Rd',
#       'London',
#       'NW1 2RA',
#       'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.528683725340635,
#        'lng': -0.1270125635626826}],
#      'lat': 51.528683725340635,
#      'lng': -0.1270125635626826,
#      'postalCode': 'NW1 2RA'},
#     'name': 'Premier Inn London St Pancras',
#     'referralId': 'v-1561753087'}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'shortName': 'Train Station', 'icon': {'pref...    False
# 1  [{'shortName': 'Train Station', 'icon': {'pref...    False
# 2  [{'shortName': 'Train Station', 'icon': {'pref...    False
# 3  [{'shortName': 'Train Station', 'icon': {'pref...    False
# 4  [{'shortName': 'Train Station', 'icon': {'pref...    False
#
#                          id                  location.address location.cc  \
# 0  4ac518f7f964a520c6af20e3                        Pancras Rd          GB
# 1  4bcc08273740b7139c756365                        Pancras Rd          GB
# 2  4e40f13dc65b4f2fdeb09bf0           St Pancras East Midland          GB
# 3  54d37e52498ef9e0d404d534                      Midland Road          GB
# 4  4f9a9abbe4b01da4fec13fa8  St Pancras International Station          GB
#
#   location.city location.country location.crossStreet  location.distance  \
# 0        London   United Kingdom            Euston Rd               2726
# 1        London   United Kingdom                  NaN               2714
# 2        London   United Kingdom                  NaN               2729
# 3        London   United Kingdom                  NaN               2723
# 4        London   United Kingdom      Platforms 11-13               2824
#
#                            location.formattedAddress  \
# 0  [Pancras Rd (Euston Rd), London, Greater Londo...
# 1  [Pancras Rd, London, Greater London, NW1 2QP, ...
# 2  [St Pancras East Midland, London, Greater Lond...
# 3  [Midland Road, London, Greater London, United ...
# 4  [St Pancras International Station (Platforms 1...
#
#                              location.labeledLatLngs  location.lat  \
# 0                                                NaN     51.531797
# 1  [{'lat': 51.53168808977662, 'lng': -0.12613641...     51.531688
# 2  [{'lat': 51.531838612994704, 'lng': -0.1269311...     51.531839
# 3  [{'lat': 51.53178652158595, 'lng': -0.12701034...     51.531787
# 4                                                NaN     51.532685
#
#    location.lng location.neighborhood location.postalCode  location.state  \
# 0     -0.126154                   NaN             NW1 2QP  Greater London
# 1     -0.126136           Kings Cross             NW1 2QP  Greater London
# 2     -0.126931                   NaN             NW1 2QP  Greater London
# 3     -0.127010                   NaN                 NaN  Greater London
# 4     -0.126549                   NaN             NW1 2QP  Greater London
#
#                                                 name    referralId  \
# 0  London St Pancras International Railway Statio...  v-1561753087
# 1  London St Pancras Eurostar Terminal (London St...  v-1561753087
# 2  St Pancras International Station (STP) — East ...  v-1561753087
# 3  St Pancras International Station (STP) — Thame...  v-1561753087
# 4  St Pancras International Station (STP) — South...  v-1561753087
#
#   venuePage.id
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                  name      categories  \
# 0   London St Pancras International Railway Statio...   Train Station
# 1   London St Pancras Eurostar Terminal (London St...   Train Station
# 2   St Pancras International Station (STP) — East ...   Train Station
# 3   St Pancras International Station (STP) — Thame...   Train Station
# 4   St Pancras International Station (STP) — South...   Train Station
# 5                                 St Paul's Cathedral          Church
# 6                        St. Paul's Church Churchyard          Garden
# 7   King's Cross St. Pancras London Underground St...   Metro Station
# 8                                   St. Paul's Church          Church
# 9                St. Pancras Renaissance Hotel London           Hotel
# 10              St. Paul's London Underground Station   Metro Station
# 11                             Grange St. Pauls Hotel           Hotel
# 12                                  St Pauls Bookshop       Bookstore
# 13                                St Patrick's Church          Church
# 14                          Iris Theatre @ St. Paul's         Theater
# 15                St Paul's and Weston Roof Pavilions     Event Space
# 16                         St. Philips Medical Centre            None
# 17                                  St Pancras Church          Church
# 18                    Club Quarters Hotel, St. Paul's           Hotel
# 19                                        St. Pancras    Neighborhood
# 20                              St Petersburg Gallery     Art Gallery
# 21                                 St. Peter's Church          Church
# 22                              St Pancras Old Church          Church
# 23                                St Patricks Canteen  Breakfast Spot
# 24                               St Paul's Churchyard            Park
# 25                                    St Paul's Crypt   Historic Site
# 26                          Pullman London St Pancras           Hotel
# 27                                St Peter's Eaton Sq          Church
# 28                          St Peter's Italian Church          Church
# 29                      Premier Inn London St Pancras           Hotel
#
#                              address  cc          city         country  \
# 0                         Pancras Rd  GB        London  United Kingdom
# 1                         Pancras Rd  GB        London  United Kingdom
# 2            St Pancras East Midland  GB        London  United Kingdom
# 3                       Midland Road  GB        London  United Kingdom
# 4   St Pancras International Station  GB        London  United Kingdom
# 5              St Paul's Church Yard  GB        London  United Kingdom
# 6                                NaN  GB        London  United Kingdom
# 7                          Euston Rd  GB        London  United Kingdom
# 8                         Bedford St  GB        London  United Kingdom
# 9                          Euston Rd  GB  King's Cross  United Kingdom
# 10                       1 Cheapside  GB        London  United Kingdom
# 11                    10 Godliman St  GB        London  United Kingdom
# 12                   Morpeth Terrace  GB      Victoria  United Kingdom
# 13                       21A Soho Sq  GB          Soho  United Kingdom
# 14                               NaN  GB           NaN  United Kingdom
# 15               Royal Festival Hall  GB        London  United Kingdom
# 16                     Sheffield St.  GB        London  United Kingdom
# 17                        Euston Rd.  GB        London  United Kingdom
# 18                   24 Ludgate Hill  GB        London  United Kingdom
# 19                               NaN  GB           NaN  United Kingdom
# 20                               NaN  GB           NaN  United Kingdom
# 21                       Vere Street  GB        London  United Kingdom
# 22                    St Pancras Way  GB        London  United Kingdom
# 23               Great Chapel Street  GB           NaN  United Kingdom
# 24             St. Paul's Churchyard  GB        London  United Kingdom
# 25             St Paul's Church Yard  GB        London  United Kingdom
# 26                 100-110 Euston Rd  GB        London  United Kingdom
# 27                         Wilton St  GB        London  United Kingdom
# 28                136 Clerkenwell Rd  GB        London  United Kingdom
# 29                      88 Euston Rd  GB        London  United Kingdom
#
#          crossStreet  distance  \
# 0          Euston Rd      2726
# 1                NaN      2714
# 2                NaN      2729
# 3                NaN      2723
# 4    Platforms 11-13      2824
# 5                NaN      2151
# 6                NaN       534
# 7                NaN      2611
# 8                NaN       511
# 9                NaN      2494
# 10     at Newgate St      2266
# 11               NaN      2055
# 12               NaN      1544
# 13        Sutton Row       944
# 14               NaN       542
# 15  Southbank Centre       780
# 16      Portugal St.      1141
# 17               NaN      2205
# 18               NaN      1979
# 19               NaN       995
# 20               NaN      1037
# 21               NaN      1630
# 22               NaN      3078
# 23               NaN      1019
# 24               NaN      2218
# 25               NaN      2164
# 26               NaN      2360
# 27               NaN      1798
# 28               NaN      2101
# 29               NaN      2378
#
#                                      formattedAddress  \
# 0   [Pancras Rd (Euston Rd), London, Greater Londo...
# 1   [Pancras Rd, London, Greater London, NW1 2QP, ...
# 2   [St Pancras East Midland, London, Greater Lond...
# 3   [Midland Road, London, Greater London, United ...
# 4   [St Pancras International Station (Platforms 1...
# 5   [St Paul's Church Yard, London, Greater London...
# 6            [London, Greater London, United Kingdom]
# 7   [Euston Rd, London, Greater London, N1 9AL, Un...
# 8   [Bedford St, London, Greater London, WC2E 9ED,...
# 9   [Euston Rd, King's Cross, Greater London, NW1 ...
# 10  [1 Cheapside (at Newgate St), London, Greater ...
# 11  [10 Godliman St, London, Greater London, EC4V ...
# 12  [Morpeth Terrace, Victoria, Greater London, SW...
# 13  [21A Soho Sq (Sutton Row), Soho, Greater Londo...
# 14                                   [United Kingdom]
# 15  [Royal Festival Hall (Southbank Centre), Londo...
# 16  [Sheffield St. (Portugal St.), London, Greater...
# 17  [Euston Rd., London, Greater London, NW1 2BA, ...
# 18  [24 Ludgate Hill, London, Greater London, EC4M...
# 19                                   [United Kingdom]
# 20                                   [United Kingdom]
# 21  [Vere Street, London, Greater London, United K...
# 22  [St Pancras Way, London, Greater London, NW1 1...
# 23              [Great Chapel Street, United Kingdom]
# 24  [St. Paul's Churchyard, London, Greater London...
# 25  [St Paul's Church Yard, London, Greater London...
# 26  [100-110 Euston Rd, London, Greater London, NW...
# 27  [Wilton St, London, Greater London, SW1 X 8, U...
# 28  [136 Clerkenwell Rd, London, Greater London, E...
# 29    [88 Euston Rd, London, NW1 2RA, United Kingdom]
#
#                                        labeledLatLngs        lat       lng  \
# 0                                                 NaN  51.531797 -0.126154
# 1   [{'lat': 51.53168808977662, 'lng': -0.12613641...  51.531688 -0.126136
# 2   [{'lat': 51.531838612994704, 'lng': -0.1269311...  51.531839 -0.126931
# 3   [{'lat': 51.53178652158595, 'lng': -0.12701034...  51.531787 -0.127010
# 4                                                 NaN  51.532685 -0.126549
# 5   [{'lat': 51.51387722554811, 'lng': -0.09842634...  51.513877 -0.098426
# 6   [{'lat': 51.511657, 'lng': -0.124331, 'label':...  51.511657 -0.124331
# 7                                                 NaN  51.530691 -0.124279
# 8   [{'lat': 51.511388712882706, 'lng': -0.1242015...  51.511389 -0.124202
# 9   [{'lat': 51.5296995, 'lng': -0.1258865, 'label...  51.529699 -0.125887
# 10  [{'lat': 51.51502318754615, 'lng': -0.09736137...  51.515023 -0.097361
# 11  [{'lat': 51.51279862863417, 'lng': -0.09932142...  51.512799 -0.099321
# 12  [{'lat': 51.49593630311686, 'lng': -0.14039115...  51.495936 -0.140391
# 13  [{'lat': 51.51550045469365, 'lng': -0.13126692...  51.515500 -0.131267
# 14  [{'lat': 51.511495, 'lng': -0.123597, 'label':...  51.511495 -0.123597
# 15  [{'lat': 51.506041789223055, 'lng': -0.1165708...  51.506042 -0.116571
# 16  [{'lat': 51.51381972126996, 'lng': -0.11489698...  51.513820 -0.114897
# 17  [{'lat': 51.52706204361282, 'lng': -0.13033390...  51.527062 -0.130334
# 18  [{'lat': 51.51388221380029, 'lng': -0.10109517...  51.513882 -0.101095
# 19  [{'lat': 51.505834428653245, 'lng': -0.1418077...  51.505834 -0.141808
# 20  [{'lat': 51.5105053183169, 'lng': -0.141716654...  51.510505 -0.141717
# 21  [{'lat': 51.51547725933961, 'lng': -0.14719478...  51.515477 -0.147195
# 22  [{'lat': 51.53492363232326, 'lng': -0.13028137...  51.534924 -0.130281
# 23  [{'lat': 51.51550295006862, 'lng': -0.13427427...  51.515503 -0.134274
# 24  [{'lat': 51.513449906831404, 'lng': -0.0971710...  51.513450 -0.097171
# 25  [{'lat': 51.51386387189887, 'lng': -0.09823322...  51.513864 -0.098233
# 26  [{'lat': 51.528521278066805, 'lng': -0.1281608...  51.528521 -0.128161
# 27  [{'lat': 51.49785380588896, 'lng': -0.14867284...  51.497854 -0.148673
# 28  [{'lat': 51.52220283972082, 'lng': -0.10898289...  51.522203 -0.108983
# 29  [{'lat': 51.528683725340635, 'lng': -0.1270125...  51.528684 -0.127013
#
#    neighborhood postalCode           state                        id
# 0           NaN    NW1 2QP  Greater London  4ac518f7f964a520c6af20e3
# 1   Kings Cross    NW1 2QP  Greater London  4bcc08273740b7139c756365
# 2           NaN    NW1 2QP  Greater London  4e40f13dc65b4f2fdeb09bf0
# 3           NaN        NaN  Greater London  54d37e52498ef9e0d404d534
# 4           NaN    NW1 2QP  Greater London  4f9a9abbe4b01da4fec13fa8
# 5           NaN   EC4M 8AD  Greater London  4ac518cef964a520f5a520e3
# 6           NaN        NaN  Greater London  55573a8c498eee8cd56fa2db
# 7           NaN     N1 9AL  Greater London  4acf786af964a520e6d320e3
# 8           NaN   WC2E 9ED  Greater London  4b2e5b98f964a520c5de24e3
# 9           NaN    NW1 2AR  Greater London  4d00c69af1605481dce59fea
# 10          NaN   EC2V 6AA  Greater London  4adc7ef3f964a520b12c21e3
# 11          NaN   EC4V 5AJ  Greater London  4bcf48860ffdce72bb58b2c0
# 12          NaN   SW1P 1EP  Greater London  4dec2a648130115d6be0c45a
# 13          NaN    W1D 4NR  Greater London  4df7693218a8a7a74302c1ab
# 14          NaN        NaN             NaN  558f0381498e1a92146e497b
# 15          NaN    SE1 8XX  Greater London  4cd6ce63fb595481fbfae550
# 16          NaN        NaN  Greater London  4b964e12f964a52004c534e3
# 17          NaN    NW1 2BA  Greater London  4ac518d2f964a52017a720e3
# 18          NaN   EC4M 7DR  Greater London  4b58e941f964a5205f7228e3
# 19          NaN        NaN             NaN  5314f6ede4b0e72a36e15ce8
# 20          NaN        NaN             NaN  511005afe4b04c8cb83038a9
# 21          NaN        NaN  Greater London  4ef7133d77c8e88f47777cad
# 22          NaN    NW1 1UL  Greater London  4c9614066b35a14356862adc
# 23          NaN        NaN             NaN  4f2bc533e4b0e6b07078e4c2
# 24          NaN      E C4M  Greater London  4d8f77893bfef04d3225af86
# 25          NaN      E C4M  Greater London  5c865b31cbcdee002c34265f
# 26          NaN    NW1 2AJ  Greater London  5010104be4b0c9392207fb78
# 27          NaN    SW1 X 8  Greater London  4b07a934f964a52046ff22e3
# 28          NaN   EC1R 5DL  Greater London  4d12331f804a2d43abc192e3
# 29          NaN    NW1 2RA             NaN  5423bcda498e0eae829271c6

# %%
dataframe_filtered.name
# Out:
# 0     London St Pancras International Railway Statio...
# 1     London St Pancras Eurostar Terminal (London St...
# 2     St Pancras International Station (STP) — East ...
# 3     St Pancras International Station (STP) — Thame...
# 4     St Pancras International Station (STP) — South...
# 5                                   St Paul's Cathedral
# 6                          St. Paul's Church Churchyard
# 7     King's Cross St. Pancras London Underground St...
# 8                                     St. Paul's Church
# 9                  St. Pancras Renaissance Hotel London
# 10                St. Paul's London Underground Station
# 11                               Grange St. Pauls Hotel
# 12                                    St Pauls Bookshop
# 13                                  St Patrick's Church
# 14                            Iris Theatre @ St. Paul's
# 15                  St Paul's and Weston Roof Pavilions
# 16                           St. Philips Medical Centre
# 17                                    St Pancras Church
# 18                      Club Quarters Hotel, St. Paul's
# 19                                          St. Pancras
# 20                                St Petersburg Gallery
# 21                                   St. Peter's Church
# 22                                St Pancras Old Church
# 23                                  St Patricks Canteen
# 24                                 St Paul's Churchyard
# 25                                      St Paul's Crypt
# 26                            Pullman London St Pancras
# 27                                  St Peter's Eaton Sq
# 28                            St Peter's Italian Church
# 29                        Premier Inn London St Pancras
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
venue_id = '4fa862b3e4b0ebff2f749f06' # ID of Harry's Italian Pizza Bar
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4fa862b3e4b0ebff2f749f06?client_id=HRYCYRRH44B02GOSP1MNOVC1AVLFQTAIT1ZFSSMIXBAFXF13&client_secret=MGW2M22FVAXDIIQOE42J55BRE0KCCSYLEUHPT3JOBICD55OR&v=20180604'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['allowMenuUrlEdit', 'tips', 'contact', 'verified', 'shortUrl', 'pageUpdates', 'hours', 'stats', 'colors', 'timeZone', 'price', 'ratingSignals', 'location', 'delivery', 'inbox', 'rating', 'bestPhoto', 'popular', 'ok', 'photos', 'listed', 'reasons', 'hasMenu', 'canonicalUrl', 'likes', 'attributes', 'categories', 'hereNow', 'beenHere', 'createdAt', 'name', 'specials', 'id', 'dislike', 'ratingColor', 'url', 'menu'])
# {'allowMenuUrlEdit': True,
#  'attributes': {'groups': [{'count': 1,
#     'items': [{'displayName': 'Price', 'displayValue': '$$', 'priceTier': 2}],
#     'name': 'Price',
#     'summary': '$$',
#     'type': 'price'},
#    {'count': 7,
#     'items': [{'displayName': 'Credit Cards',
#       'displayValue': 'Yes (incl. American Express)'}],
#     'name': 'Credit Cards',
#     'summary': 'Credit Cards',
#     'type': 'payments'},
#    {'count': 1,
#     'items': [{'displayName': 'Outdoor Seating', 'displayValue': 'Yes'}],
#     'name': 'Outdoor Seating',
#     'summary': 'Outdoor Seating',
#     'type': 'outdoorSeating'},
#    {'count': 8,
#     'items': [{'displayName': 'Brunch', 'displayValue': 'Brunch'},
#      {'displayName': 'Lunch', 'displayValue': 'Lunch'},
#      {'displayName': 'Dinner', 'displayValue': 'Dinner'},
#      {'displayName': 'Happy Hour', 'displayValue': 'Happy Hour'}],
#     'name': 'Menus',
#     'summary': 'Happy Hour, Brunch & more',
#     'type': 'serves'},
#    {'count': 5,
#     'items': [{'displayName': 'Beer', 'displayValue': 'Beer'},
#      {'displayName': 'Wine', 'displayValue': 'Wine'},
#      {'displayName': 'Cocktails', 'displayValue': 'Cocktails'}],
#     'name': 'Drinks',
#     'summary': 'Beer, Wine & Cocktails',
#     'type': 'drinks'},
#    {'count': 5,
#     'items': [{'displayName': 'Delivery', 'displayValue': 'Delivery'}],
#     'name': 'Dining Options',
#     'summary': 'Delivery',
#     'type': 'diningOptions'}]},
#  'beenHere': {'count': 0,
#   'lastCheckinExpiredAt': 0,
#   'marked': False,
#   'unconfirmedCount': 0},
#  'bestPhoto': {'createdAt': 1336776717,
#   'height': 640,
#   'id': '4fad980de4b091b4626c3633',
#   'prefix': 'https://fastly.4sqi.net/img/general/',
#   'source': {'name': 'Foursquare for Android',
#    'url': 'https://foursquare.com/download/#/android'},
#   'suffix': '/ya1iQFI7pLjuIJp1PGDKlrZS3OJdHCF7tpILMmjv_2w.jpg',
#   'visibility': 'public',
#   'width': 480},
#  'canonicalUrl': 'https://foursquare.com/v/harrys-italian-pizza-bar/4fa862b3e4b0ebff2f749f06',
#  'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#     'suffix': '.png'},
#    'id': '4bf58dd8d48988d1ca941735',
#    'name': 'Pizza Place',
#    'pluralName': 'Pizza Places',
#    'primary': True,
#    'shortName': 'Pizza'},
#   {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#     'suffix': '.png'},
#    'id': '4bf58dd8d48988d110941735',
#    'name': 'Italian Restaurant',
#    'pluralName': 'Italian Restaurants',
#    'shortName': 'Italian'}],
#  'colors': {'algoVersion': 3,
#   'highlightColor': {'photoId': '4fad980de4b091b4626c3633',
#    'value': -13619152},
#   'highlightTextColor': {'photoId': '4fad980de4b091b4626c3633', 'value': -1}},
#  'contact': {'formattedPhone': '(212) 608-1007', 'phone': '2126081007'},
#  'createdAt': 1336435379,
#  'delivery': {'id': '294544',
#   'provider': {'icon': {'name': '/delivery_provider_seamless_20180129.png',
#     'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#     'sizes': [40, 50]},
#    'name': 'seamless'},
#   'url': 'https://www.seamless.com/menu/harrys-italian-pizza-bar-225-murray-st-new-york/294544?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=294544'},
#  'dislike': False,
#  'hasMenu': True,
#  'hereNow': {'count': 0, 'groups': [], 'summary': 'Nobody here'},
#  'hours': {'dayData': [],
#   'isLocalHoliday': False,
#   'isOpen': True,
#   'richStatus': {'entities': [], 'text': 'Open until Midnight'},
#   'status': 'Open until Midnight',
#   'timeframes': [{'days': 'Mon–Wed, Sun',
#     'open': [{'renderedTime': '11:30 AM–11:00 PM'}],
#     'segments': []},
#    {'days': 'Thu–Sat',
#     'includesToday': True,
#     'open': [{'renderedTime': '11:30 AM–Midnight'}],
#     'segments': []}]},
#  'id': '4fa862b3e4b0ebff2f749f06',
#  'inbox': {'count': 0, 'items': []},
#  'likes': {'count': 120,
#   'groups': [{'count': 120, 'items': [], 'type': 'others'}],
#   'summary': '120 Likes'},
#  'listed': {'count': 54,
#   'groups': [{'count': 54,
#     'items': [{'canonicalUrl': 'https://foursquare.com/becca_mcarthur/list/manhattan-haunts',
#       'collaborative': False,
#       'createdAt': 1336094672,
#       'description': '',
#       'editable': False,
#       'followers': {'count': 22},
#       'id': '4fa32fd0e4b04193744746b1',
#       'listItems': {'count': 187,
#        'items': [{'createdAt': 1342934485,
#          'id': 'v4fa862b3e4b0ebff2f749f06'}]},
#       'name': 'Manhattan Haunts',
#       'photo': {'createdAt': 1317849414,
#        'height': 330,
#        'id': '4e8cc9461081e3b3544e12e5',
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/0NLVU2HC1JF4DXIMKWUFW3QBUT31DC11EFNYYHMJG3NDWAPS.jpg',
#        'user': {'firstName': 'Time Out New York',
#         'gender': 'none',
#         'id': '742542',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/XXHKCBSQHBORZNSR.jpg'},
#         'type': 'page'},
#        'visibility': 'public',
#        'width': 492},
#       'public': True,
#       'type': 'others',
#       'updatedAt': 1380845377,
#       'url': '/becca_mcarthur/list/manhattan-haunts',
#       'user': {'firstName': 'Becca',
#        'gender': 'female',
#        'id': '24592223',
#        'lastName': 'M',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/24592223-RAW2UYM0GIB1U40K.jpg'}}},
#      {'canonicalUrl': 'https://foursquare.com/kinosfault/list/usa-nyc-man-fidi',
#       'collaborative': False,
#       'createdAt': 1336836475,
#       'description': 'Where to go for decent eats in the restaurant wasteland of Downtown NYC aka FiDi, along with Tribeca & Battery Park City.',
#       'editable': False,
#       'followers': {'count': 20},
#       'id': '4fae817be4b085f6b2a74d19',
#       'listItems': {'count': 273,
#        'items': [{'createdAt': 1373909433,
#          'id': 'v4fa862b3e4b0ebff2f749f06'}]},
#       'name': 'USA NYC MAN FiDi',
#       'photo': {'createdAt': 1436043666,
#        'height': 960,
#        'id': '55984992498e13ba75e353bb',
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/12113441_iOa6Uh-Xi8bhj2-gpzkkw8MKiAIs7RmOcz_RM7m8ink.jpg',
#        'user': {'firstName': 'Kino',
#         'gender': 'male',
#         'id': '12113441',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/12113441-K5HTHFLU2MUCM0CM.jpg'}},
#        'visibility': 'public',
#        'width': 540},
#       'public': True,
#       'type': 'others',
#       'updatedAt': 1556754919,
#       'url': '/kinosfault/list/usa-nyc-man-fidi',
#       'user': {'firstName': 'Kino',
#        'gender': 'male',
#        'id': '12113441',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/12113441-K5HTHFLU2MUCM0CM.jpg'}}},
#      {'canonicalUrl': 'https://foursquare.com/rickr7/list/nyc-resturants',
#       'collaborative': True,
#       'createdAt': 1339944944,
#       'description': '',
#       'editable': False,
#       'followers': {'count': 12},
#       'id': '4fddeff0e4b0e078037ac0d3',
#       'listItems': {'count': 195,
#        'items': [{'createdAt': 1514680908,
#          'id': 't54ed3b13498e857fd7dbb6fc'}]},
#       'name': 'NYC Resturants',
#       'photo': {'createdAt': 1349704979,
#        'height': 800,
#        'id': '5072dd13e4b09145cdf782d1',
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/208205_fGh2OuAZ9qJ4agbAA5wMVNOSIm9kNUlRtNwj1N-adqg.jpg',
#        'user': {'firstName': 'Thalia',
#         'gender': 'female',
#         'id': '208205',
#         'lastName': 'K',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/SNOOLCAW2AG04ZKD.jpg'}},
#        'visibility': 'public',
#        'width': 800},
#       'public': True,
#       'type': 'others',
#       'updatedAt': 1559554908,
#       'url': '/rickr7/list/nyc-resturants',
#       'user': {'firstName': 'Richard',
#        'gender': 'male',
#        'id': '21563126',
#        'lastName': 'R',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/21563126_v05J1KPw_SVj6Ehq9g8B9jeAGjFUMsU5QGl-NZ8inUQ7pKQm5bKplW37EmR7jS2A7GYPBBAtl.jpg'}}},
#      {'canonicalUrl': 'https://foursquare.com/sweetiewill/list/foodie-love-in-ny--02',
#       'collaborative': False,
#       'createdAt': 1382467210,
#       'description': '',
#       'editable': False,
#       'followers': {'count': 7},
#       'id': '5266c68a498e7c667807fe09',
#       'listItems': {'count': 200,
#        'items': [{'createdAt': 1386809936,
#          'id': 'v4fa862b3e4b0ebff2f749f06'}]},
#       'name': 'Foodie Love in NY - 02',
#       'public': True,
#       'type': 'others',
#       'updatedAt': 1391995585,
#       'url': '/sweetiewill/list/foodie-love-in-ny--02',
#       'user': {'firstName': 'WiLL',
#        'gender': 'male',
#        'id': '547977',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/-Q5NYGDMFDMOITQRR.jpg'}}}],
#     'name': 'Lists from other people',
#     'type': 'others'}]},
#  'location': {'address': '225 Murray St',
#   'cc': 'US',
#   'city': 'New York',
#   'country': 'United States',
#   'formattedAddress': ['225 Murray St', 'New York, NY 10282', 'United States'],
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 40.71521779064671,
#     'lng': -74.01473940209351}],
#   'lat': 40.71521779064671,
#   'lng': -74.01473940209351,
#   'postalCode': '10282',
#   'state': 'NY'},
#  'menu': {'anchor': 'View Menu',
#   'label': 'Menu',
#   'mobileUrl': 'https://foursquare.com/v/4fa862b3e4b0ebff2f749f06/device_menu',
#   'type': 'Menu',
#   'url': 'https://foursquare.com/v/harrys-italian-pizza-bar/4fa862b3e4b0ebff2f749f06/menu'},
#  'name': "Harry's Italian Pizza Bar",
#  'ok': False,
#  'pageUpdates': {'count': 0, 'items': []},
#  'photos': {'count': 149,
#   'groups': [{'count': 0,
#     'items': [],
#     'name': "Friends' check-in photos",
#     'type': 'checkin'},
#    {'count': 149,
#     'items': [{'createdAt': 1336776717,
#       'height': 640,
#       'id': '4fad980de4b091b4626c3633',
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'source': {'name': 'Foursquare for Android',
#        'url': 'https://foursquare.com/download/#/android'},
#       'suffix': '/ya1iQFI7pLjuIJp1PGDKlrZS3OJdHCF7tpILMmjv_2w.jpg',
#       'user': {'firstName': 'Leony',
#        'gender': 'none',
#        'id': '13676709',
#        'lastName': 'N',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/T0ANFNGNMCHUDEUE.jpg'}},
#       'visibility': 'public',
#       'width': 480}],
#     'name': 'Venue photos',
#     'type': 'venue'}],
#   'summary': '0 photos'},
#  'popular': {'isLocalHoliday': False,
#   'isOpen': False,
#   'timeframes': [{'days': 'Today',
#     'includesToday': True,
#     'open': [{'renderedTime': 'Noon–3:00 PM'},
#      {'renderedTime': '5:00 PM–11:00 PM'}],
#     'segments': []},
#    {'days': 'Sat',
#     'open': [{'renderedTime': 'Noon–11:00 PM'}],
#     'segments': []},
#    {'days': 'Sun',
#     'open': [{'renderedTime': 'Noon–3:00 PM'},
#      {'renderedTime': '5:00 PM–8:00 PM'}],
#     'segments': []},
#    {'days': 'Mon',
#     'open': [{'renderedTime': 'Noon–2:00 PM'},
#      {'renderedTime': '6:00 PM–8:00 PM'}],
#     'segments': []},
#    {'days': 'Tue–Thu',
#     'open': [{'renderedTime': 'Noon–2:00 PM'},
#      {'renderedTime': '5:00 PM–10:00 PM'}],
#     'segments': []}]},
#  'price': {'currency': '$', 'message': 'Moderate', 'tier': 2},
#  'rating': 7.1,
#  'ratingColor': 'C5DE35',
#  'ratingSignals': 214,
#  'reasons': {'count': 1,
#   'items': [{'reasonName': 'rawLikesReason',
#     'summary': 'Lots of people like this place',
#     'type': 'general'}]},
#  'shortUrl': 'http://4sq.com/JNblHV',
#  'specials': {'count': 0, 'items': []},
#  'stats': {'tipCount': 57},
#  'timeZone': 'America/New_York',
#  'tips': {'count': 57,
#   'groups': [{'count': 57,
#     'items': [{'agreeCount': 4,
#       'canonicalUrl': 'https://foursquare.com/item/53d27909498e0523841340b6',
#       'createdAt': 1406302473,
#       'disagreeCount': 0,
#       'id': '53d27909498e0523841340b6',
#       'lang': 'en',
#       'likes': {'count': 4,
#        'groups': [{'count': 4,
#          'items': [{'firstName': 'P.',
#            'gender': 'male',
#            'id': '369426',
#            'lastName': 'M',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/JPQYUWJKUT0H2OO4.jpg'}},
#           {'firstName': 'Diane',
#            'gender': 'female',
#            'id': '87587879',
#            'lastName': 'D',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/87587879-ESLRSZLQ2CBE2P4W.jpg'}},
#           {'firstName': 'Tim',
#            'gender': 'male',
#            'id': '87591341',
#            'lastName': 'S',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/-Z4YK4VKE0JSVXIY1.jpg'}},
#           {'firstName': 'TenantKing.com',
#            'gender': 'none',
#            'id': '87473404',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/87473404-HI5DTBTK0HX401CA.png'},
#            'type': 'page'}],
#          'type': 'others'}],
#        'summary': '4 likes'},
#       'logView': True,
#       'text': "Harry's Italian Pizza bar is known for it's amazing pizza, but did you know that the brunches here are amazing too? Try the Nutella French toast and we know you'll be sold.",
#       'todo': {'count': 0},
#       'type': 'user',
#       'user': {'firstName': 'TenantKing.com',
#        'gender': 'none',
#        'id': '87473404',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/87473404-HI5DTBTK0HX401CA.png'},
#        'type': 'page'}}],
#     'name': 'All tips',
#     'type': 'others'}]},
#  'url': 'http://harrysitalian.com',
#  'verified': False}

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %%
venue_id = '4f3232e219836c91c7bfde94' # ID of Conca Cucina Italian Restaurant
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %%
venue_id = '3fd66200f964a520f4e41ee3' # ID of Ecco
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 7.9

# %%
result['response']['venue']['tips']['count']
# Out:
# 17

# %%
## Ecco Tips
limit = 15 # set limit to be greater than or equal to the total number of tips
url = 'https://api.foursquare.com/v2/venues/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION, limit)

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d16764b6bdee6002c080ab9'},
#  'response': {'tips': {'count': 17,
#    'items': [{'agreeCount': 3,
#      'authorInteractionType': 'liked',
#      'canonicalUrl': 'https://foursquare.com/item/5ab1cb46c9a517174651d3fe',
#      'createdAt': 1521601350,
#      'disagreeCount': 0,
#      'id': '5ab1cb46c9a517174651d3fe',
#      'lang': 'en',
#      'lastUpvoteTimestamp': 1557868336,
#      'lastVoteText': 'Upvoted May 14',
#      'likes': {'count': 0, 'groups': []},
#      'logView': True,
#      'text': 'A+ Italian food! Trust me on this: my mom’s side of the family is 100% Italian. I was born and bred to know good pasta when I see it, and Ecco is one of my all-time NYC favorites',
#      'todo': {'count': 0},
#      'type': 'user',
#      'user': {'firstName': 'Nick',
#       'gender': 'male',
#       'id': '484542633',
#       'lastName': 'E',
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/484542633_mK2Yum7T_7Tn9fWpndidJsmw2Hof_6T5vJBKCHPLMK5OL-U5ZiJGj51iwBstcpDLYa3Zvhvis.jpg'}}}]}}}

# %%
tips = results['response']['tips']['items']

tip = results['response']['tips']['items'][0]
tip.keys()
# Out:
# dict_keys(['lang', 'logView', 'text', 'agreeCount', 'disagreeCount', 'lastUpvoteTimestamp', 'user', 'likes', 'type', 'id', 'todo', 'createdAt', 'canonicalUrl', 'lastVoteText', 'authorInteractionType'])

# %%
user_id = '484542633' # user ID with most agree counts and complete profile

url = 'https://api.foursquare.com/v2/users/{}?client_id={}&client_secret={}&v={}'.format(user_id, CLIENT_ID, CLIENT_SECRET, VERSION) # define URL

# send GET request
results = requests.get(url).json()
user_data = results['response']['user']

# display features associated with user
user_data.keys()
# Out:
# dict_keys(['homeCity', 'lists', 'firstName', 'lenses', 'lastName', 'contact', 'friends', 'gender', 'mayorships', 'tips', 'checkins', 'id', 'canonicalUrl', 'photo', 'type', 'photos', 'bio'])

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Ecco


# add Ecco as a red circle mark
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    popup='Ecco',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(venues_map)


# add popular spots to the map as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# define URL
url = 'https://api.foursquare.com/v2/venues/trending?client_id={}&client_secret={}&ll={},{}&v={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION)

# send GET request and get trending venues
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d167665fd16bb002cdabc8b'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/departmentstore_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1f6941735',
#       'name': 'Department Store',
#       'pluralName': 'Department Stores',
#       'primary': True,
#       'shortName': 'Department Store'}],
#     'id': '4ae5b238f964a52087a121e3',
#     'location': {'address': '400 Oxford St',
#      'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'distance': 1927,
#      'formattedAddress': ['400 Oxford St',
#       'London',
#       'Greater London',
#       'W1A 1AB',
#       'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.51464,
#        'lng': -0.152864}],
#      'lat': 51.51464,
#      'lng': -0.152864,
#      'postalCode': 'W1A 1AB',
#      'state': 'Greater London'},
#     'name': 'Selfridges & Co'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'id': '5c75875e1c9e2e002527a174',
#     'location': {'address': '40-41 Great Castle St',
#      'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'distance': 1327,
#      'formattedAddress': ['40-41 Great Castle St',
#       'London',
#       'Greater London',
#       'W1W 8LU',
#       'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.516185764675825,
#        'lng': -0.14046166652284045}],
#      'lat': 51.516185764675825,
#      'lng': -0.14046166652284045,
#      'postalCode': 'W1W 8LU',
#      'state': 'Greater London'},
#     'name': 'JOLT'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'primary': True,
#       'shortName': 'Restaurant'}],
#     'id': '586f8ecf6119f44c251632ce',
#     'location': {'address': '30 Shepherd Market',
#      'cc': 'GB',
#      'city': 'Mayfair',
#      'country': 'United Kingdom',
#      'distance': 1306,
#      'formattedAddress': ['30 Shepherd Market',
#       'Mayfair',
#       'Greater London',
#       'W1J 7QN',
#       'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.50650181288355,
#        'lng': -0.14646190547074883}],
#      'lat': 51.50650181288355,
#      'lng': -0.14646190547074883,
#      'postalCode': 'W1J 7QN',
#      'state': 'Greater London'},
#     'name': 'Ferdi'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/neighborhood_',
#        'suffix': '.png'},
#       'id': '50aa9e094b90af0d42d5de0d',
#       'name': 'City',
#       'pluralName': 'Cities',
#       'primary': True,
#       'shortName': 'City'}],
#     'id': '4e10c02045dde6c62dcd8b19',
#     'location': {'cc': 'GB',
#      'city': 'Greater London',
#      'country': 'United Kingdom',
#      'distance': 42,
#      'formattedAddress': ['Greater London', 'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.50767403407925,
#        'lng': -0.12788772583007812}],
#      'lat': 51.50767403407925,
#      'lng': -0.12788772583007812,
#      'state': 'Greater London'},
#     'name': 'London'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_art_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d18f941735',
#       'name': 'Art Museum',
#       'pluralName': 'Art Museums',
#       'primary': True,
#       'shortName': 'Art Museum'}],
#     'id': '4ac518d3f964a52076a720e3',
#     'location': {'address': '53 Bankside',
#      'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'distance': 1953,
#      'formattedAddress': ['53 Bankside',
#       'London',
#       'Greater London',
#       'SE1 9TG',
#       'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.50770408386703,
#        'lng': -0.0994563102722168}],
#      'lat': 51.50770408386703,
#      'lng': -0.0994563102722168,
#      'postalCode': 'SE1 9TG',
#      'state': 'Greater London'},
#     'name': 'Tate Modern'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d164941735',
#       'name': 'Plaza',
#       'pluralName': 'Plazas',
#       'primary': True,
#       'shortName': 'Plaza'}],
#     'id': '4c9c6a059c48236a1cb14dee',
#     'location': {'address': 'Piccadilly',
#      'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'crossStreet': 'Regent St',
#      'distance': 567,
#      'formattedAddress': ['Piccadilly (Regent St)',
#       'London',
#       'Greater London',
#       'W1D 1NN',
#       'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.50996110016709,
#        'lng': -0.1346522569656372}],
#      'lat': 51.50996110016709,
#      'lng': -0.1346522569656372,
#      'neighborhood': 'Piccadilly',
#      'postalCode': 'W1D 1NN',
#      'state': 'Greater London'},
#     'name': 'Piccadilly Circus'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'primary': True,
#       'shortName': 'Asian'}],
#     'id': '4e805fb2dab41c952c505ffc',
#     'location': {'address': '50a Berkeley St',
#      'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'distance': 1054,
#      'formattedAddress': ['50a Berkeley St',
#       'London',
#       'Greater London',
#       'W1J 8HA',
#       'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.507767103762376,
#        'lng': -0.14284957683152608}],
#      'lat': 51.507767103762376,
#      'lng': -0.14284957683152608,
#      'neighborhood': 'Mayfair',
#      'postalCode': 'W1J 8HA',
#      'state': 'Greater London'},
#     'name': 'Novikov',
#     'venuePage': {'id': '121043084'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'primary': True,
#       'shortName': 'Pizza'}],
#     'id': '55aab651498e32cd64c46495',
#     'location': {'address': '36-39 Maiden Ln',
#      'cc': 'GB',
#      'city': 'Covent Garden',
#      'country': 'United Kingdom',
#      'distance': 522,
#      'formattedAddress': ['36-39 Maiden Ln',
#       'Covent Garden',
#       'Greater London',
#       'WC2E 7LJ',
#       'United Kingdom'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.510908608488776,
#        'lng': -0.12277987896741278}],
#      'lat': 51.510908608488776,
#      'lng': -0.12277987896741278,
#      'postalCode': 'WC2E 7LJ',
#      'state': 'Greater London'},
#     'name': 'Franco Manca'}]}}

# %%
if len(results['response']['venues']) == 0:
    trending_venues_df = 'No trending venues are available at the moment!'
    
else:
    trending_venues = results['response']['venues']
    trending_venues_df = json_normalize(trending_venues)

    # filter columns
    columns_filtered = ['name', 'categories'] + ['location.distance', 'location.city', 'location.postalCode', 'location.state', 'location.country', 'location.lat', 'location.lng']
    trending_venues_df = trending_venues_df.loc[:, columns_filtered]

    # filter the category for each row
    trending_venues_df['categories'] = trending_venues_df.apply(get_category_type, axis=1)

# %%
trending_venues_df
# Out:
#                 name        categories  location.distance   location.city  \
# 0    Selfridges & Co  Department Store               1927          London
# 1               JOLT       Coffee Shop               1327          London
# 2              Ferdi        Restaurant               1306         Mayfair
# 3             London              City                 42  Greater London
# 4        Tate Modern        Art Museum               1953          London
# 5  Piccadilly Circus             Plaza                567          London
# 6            Novikov  Asian Restaurant               1054          London
# 7       Franco Manca       Pizza Place                522   Covent Garden
#
#   location.postalCode  location.state location.country  location.lat  \
# 0             W1A 1AB  Greater London   United Kingdom     51.514640
# 1             W1W 8LU  Greater London   United Kingdom     51.516186
# 2             W1J 7QN  Greater London   United Kingdom     51.506502
# 3                 NaN  Greater London   United Kingdom     51.507674
# 4             SE1 9TG  Greater London   United Kingdom     51.507704
# 5             W1D 1NN  Greater London   United Kingdom     51.509961
# 6             W1J 8HA  Greater London   United Kingdom     51.507767
# 7            WC2E 7LJ  Greater London   United Kingdom     51.510909
#
#    location.lng
# 0     -0.152864
# 1     -0.140462
# 2     -0.146462
# 3     -0.127888
# 4     -0.099456
# 5     -0.134652
# 6     -0.142850
# 7     -0.122780

# %%
if len(results['response']['venues']) == 0:
    venues_map = 'Cannot generate visual as no trending venues are available at the moment!'

else:
    venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Ecco


    # add Ecco as a red circle mark
    folium.features.CircleMarker(
        [latitude, longitude],
        radius=10,
        popup='Ecco',
        fill=True,
        color='red',
        fill_color='red',
        fill_opacity=0.6
    ).add_to(venues_map)


    # add the trending venues as blue circle markers
    for lat, lng, label in zip(trending_venues_df['location.lat'], trending_venues_df['location.lng'], trending_venues_df['name']):
        folium.features.CircleMarker(
            [lat, lng],
            radius=5,
            poup=label,
            fill=True,
            color='blue',
            fill_color='blue',
            fill_opacity=0.6
        ).add_to(venues_map)

# %%
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
radius = 500

# %%
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=HRYCYRRH44B02GOSP1MNOVC1AVLFQTAIT1ZFSSMIXBAFXF13&client_secret=MGW2M22FVAXDIIQOE42J55BRE0KCCSYLEUHPT3JOBICD55OR&ll=40.715337,-74.008848&v=20180604&radius=500&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d1635506e46500039c1311b'},
#  'response': {'groups': [{'items': [{'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4af5d65ff964a52091fd21e3-0',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1f8941735',
#          'name': 'Furniture / Home Store',
#          'pluralName': 'Furniture / Home Stores',
#          'primary': True,
#          'shortName': 'Furniture / Home'}],
#        'id': '4af5d65ff964a52091fd21e3',
#        'location': {'address': '57 Warren St',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'Church St',
#         'distance': 73,
#         'formattedAddress': ['57 Warren St (Church St)',
#          'New York, NY 10007',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.71482437714839,
#           'lng': -74.00940425461492}],
#         'lat': 40.71482437714839,
#         'lng': -74.00940425461492,
#         'neighborhood': 'Tribeca',
#         'postalCode': '10007',
#         'state': 'NY'},
#        'name': 'Korin',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '33104775'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-54148bc6498ea7bb8c05b70a-1',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'primary': True,
#          'shortName': 'Vegetarian / Vegan'}],
#        'id': '54148bc6498ea7bb8c05b70a',
#        'location': {'address': '83 Murray St',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'btwn Greenwich St & W Broadway',
#         'distance': 202,
#         'formattedAddress': ['83 Murray St (btwn Greenwich St & W Broadway)',
#          'New York, NY 10007',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.71478769908051,
#           'lng': -74.0111317502157}],
#         'lat': 40.71478769908051,
#         'lng': -74.0111317502157,
#         'postalCode': '10007',
#         'state': 'NY'},
#        'name': 'Juice Press',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c154c9a77cea593c401d260-2',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'primary': True,
#          'shortName': 'Bakery'}],
#        'id': '4c154c9a77cea593c401d260',
#        'location': {'address': '25 Murray St',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'at Church St',
#         'distance': 187,
#         'formattedAddress': ['25 Murray St (at Church St)',
#          'New York, NY 10007',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.713652845301894,
#           'lng': -74.0088038953017}],
#         'lat': 40.713652845301894,
#         'lng': -74.0088038953017,
#         'postalCode': '10007',
#         'state': 'NY'},
#        'name': 'Takahachi Bakery',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '85495566'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4a8f2f39f964a520471420e3-3',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'primary': True,
#          'shortName': 'Sushi'}],
#        'id': '4a8f2f39f964a520471420e3',
#        'location': {'address': '145 Duane St',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'btwn W Broadway & Church St',
#         'distance': 146,
#         'formattedAddress': ['145 Duane St (btwn W Broadway & Church St)',
#          'New York, NY 10013',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.71652647412374,
#           'lng': -74.00810108466207}],
#         'lat': 40.71652647412374,
#         'lng': -74.00810108466207,
#         'postalCode': '10013',
#         'state': 'NY'},
#        'name': 'Takahachi',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4adcf23cf964a520cc6221e3-4',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_wineshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d119951735',
#          'name': 'Wine Shop',
#          'pluralName': 'Wine Shops',
#          'primary': True,
#          'shortName': 'Wine Shop'}],
#        'id': '4adcf23cf964a520cc6221e3',
#        'location': {'address': '148 Chambers St',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'btwn West Broadway & Hudson St',
#         'distance': 88,
#         'formattedAddress': ['148 Chambers St (btwn West Broadway & Hudson St)',
#          'New York, NY 10007',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.715773063928374,
#           'lng': -74.00971823312332}],
#         'lat': 40.715773063928374,
#         'lng': -74.00971823312332,
#         'postalCode': '10007',
#         'state': 'NY'},
#        'name': 'Chambers Street Wines',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-57ad129c498e05b086594d72-5',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1ed941735',
#          'name': 'Spa',
#          'pluralName': 'Spas',
#          'primary': True,
#          'shortName': 'Spa'}],
#        'id': '57ad129c498e05b086594d72',
#        'location': {'address': '92 Reade St',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'distance': 86,
#         'formattedAddress': ['92 Reade St',
#          'New York, NY 10013',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.715598486687675,
#           'lng': -74.00788227511288}],
#         'lat': 40.715598486687675,
#         'lng': -74.00788227511288,
#         'postalCode': '10013',
#         'state': 'NY'},
#        'name': 'Heyday',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b747291f964a52042dd2de3-6',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/antique_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d116951735',
#          'name': 'Antique Shop',
#          'pluralName': 'Antique Shops',
#          'primary': True,
#          'shortName': 'Antiques'}],
#        'id': '4b747291f964a52042dd2de3',
#        'location': {'address': '122 Chambers St',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'distance': 8,
#         'formattedAddress': ['122 Chambers St',
#          'New York, NY 10007',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.71528423132827,
#           'lng': -74.00878093952018}],
#         'lat': 40.71528423132827,
#         'lng': -74.00878093952018,
#         'postalCode': '10007',
#         'state': 'NY'},
#        'name': 'Philip Williams Posters',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4a6e331af964a52031d41fe3-7',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '4a6e331af964a52031d41fe3',
#        'location': {'address': '54 Murray Street',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'at W Broadway',
#         'distance': 154,
#         'formattedAddress': ['54 Murray Street (at W Broadway)',
#          'New York, NY 10007',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.71409860726041,
#           'lng': -74.0096857179283}],
#         'lat': 40.71409860726041,
#         'lng': -74.0096857179283,
#         'postalCode': '10007',
#         'state': 'NY'},
#        'name': 'Equinox Tribeca',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-50ba9119e4b071a4bae6dc10-8',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/falafel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10b941735',
#          'name': 'Falafel Restaurant',
#          'pluralName': 'Falafel Restaurants',
#          'primary': True,
#          'shortName': 'Falafel'}],
#        'id': '50ba9119e4b071a4bae6dc10',
#        'location': {'address': '88 Reade St',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'at Church St',
#         'distance': 97,
#         'formattedAddress': ['88 Reade St (at Church St)',
#          'New York, NY 10013',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.71553710116416,
#           'lng': -74.00772452925565}],
#         'lat': 40.71553710116416,
#         'lng': -74.00772452925565,
#         'postalCode': '10013',
#         'state': 'NY'},
#        'name': 'Nish Nūsh',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '93083181'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5171b5cc011cef9833bbb787-9',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'primary': True,
#          'shortName': 'Café'}],
#        'delivery': {'id': '296363',
#         'provider': {'icon': {'name': '/delivery_provider_seamless_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'seamless'},
#         'url': 'https://www.seamless.com/menu/mulberry--vine-73-warren-st-new-york/296363?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=296363'},
#        'id': '5171b5cc011cef9833bbb787',
#        'location': {'address': '73 Warren St',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'btwn W Broadway & Greenwich St',
#         'distance': 117,
#         'formattedAddress': ['73 Warren St (btwn W Broadway & Greenwich St)',
#          'New York, NY 10007',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.71517693966315,
#           'lng': -74.01022747778285}],
#         'lat': 40.71517693966315,
#         'lng': -74.01022747778285,
#         'postalCode': '10007',
#         'state': 'NY'},
#        'name': 'Mulberry & Vine',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '55591598'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-545c0436498e798e22ce4b2a-10',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'primary': True,
#          'shortName': 'American'}],
#        'id': '545c0436498e798e22ce4b2a',
#        'location': {'address': '85 W Broadway',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'at Chambers St',
#         'distance': 29,
#         'formattedAddress': ['85 W Broadway (at Chambers St)',
#          'New York, NY 10007',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.715486585249735,
#           'lng': -74.00913313510836}],
#         'lat': 40.715486585249735,
#         'lng': -74.00913313510836,
#         'postalCode': '10007',
#         'state': 'NY'},
#        'name': 'Little Park',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '102902274'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-433b2e80f964a52036281fe3-11',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/stripclub_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1d6941735',
#          'name': 'Strip Club',
#          'pluralName': 'Strip Clubs',
#          'primary': True,
#          'shortName': 'Strip Club'}],
#        'id': '433b2e80f964a52036281fe3',
#        'location': {'address': '59 Murray St',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'Church St & West Broadway',
#         'distance': 136,
#         'formattedAddress': ['59 Murray St (Church St & West Broadway)',
#          'New York, NY 10007',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.71435,
#           'lng': -74.0098}],
#         'lat': 40.71435,
#         'lng': -74.0098,
#         'postalCode': '10007',
#         'state': 'NY'},
#        'name': 'FlashDancers Downtown',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '79597613'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-49bc3b0af964a52020541fe3-12',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'primary': True,
#          'shortName': 'Grocery Store'}],
#        'id': '49bc3b0af964a52020541fe3',
#        'location': {'address': '270 Greenwich Street',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'at Warren St',
#         'distance': 214,
#         'formattedAddress': ['270 Greenwich Street (at Warren St)',
#          'New York, NY 10007',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.715579155420606,
#           'lng': -74.01136823958119}],
#         'lat': 40.715579155420606,
#         'lng': -74.01136823958119,
#         'neighborhood': 'Tribeca',
#         'postalCode': '10007',
#         'state': 'NY'},
#        'name': 'Whole Foods Market',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-53910ac3498e57a5dc0eb160-13',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '53910ac3498e57a5dc0eb160',
#        'location': {'address': '97 Reade St',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'bet W Broadway & Church St',
#         'distance': 79,
#         'formattedAddress': ['97 Reade St (bet W Broadway & Church St)',
#          'New York, NY 10013',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.7156286200256,
#           'lng': -74.0079922583853}],
#         'lat': 40.7156286200256,
#         'lng': -74.0079922583853,
#         'neighborhood': 'Tribeca',
#         'postalCode': '10013',
#         'state': 'NY'},
#        'name': 'Exceed Physical Culture',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4cd89eeb6e8b5941660c64d2-14',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d11e941735',
#          'name': 'Cocktail Bar',
#          'pluralName': 'Cocktail Bars',
#          'primary': True,
#          'shortName': 'Cocktail'}],
#        'id': '4cd89eeb6e8b5941660c64d2',
#        'location': {'address': '159 Duane St',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'btwn Hudson St. & W Broadway',
#         'distance': 157,
#         'formattedAddress': ['159 Duane St (btwn Hudson St. & W Broadway)',
#          'New York, NY 10013',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.71674084163369,
#           'lng': -74.0086664438893}],
#         'lat': 40.71674084163369,
#         'lng': -74.0086664438893,
#         'postalCode': '10013',
#         'state': 'NY'},
#        'name': 'Weather Up',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4dadcb124df0522cc5622202-15',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'primary': True,
#          'shortName': 'American'}],
#        'id': '4dadcb124df0522cc5622202',
#        'location': {'address': '135 W Broadway',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'between Duane St & Thomas St',
#         'distance': 170,
#         'formattedAddress': ['135 W Broadway (between Duane St & Thomas St)',
#          'New York, NY 10013',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.71679304855808,
#           'lng': -74.00821998878457}],
#         'lat': 40.71679304855808,
#         'lng': -74.00821998878457,
#         'postalCode': '10013',
#         'state': 'NY'},
#        'name': "Tiny's and the Bar Upstairs",
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '84453413'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b6469d3f964a52037b12ae3-16',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d114951735',
#          'name': 'Bookstore',
#          'pluralName': 'Bookstores',
#          'primary': True,
#          'shortName': 'Bookstore'}],
#        'id': '4b6469d3f964a52037b12ae3',
#        'location': {'address': '58 Warren St',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'at W Broadway',
#         'distance': 71,
#         'formattedAddress': ['58 Warren St (at W Broadway)',
#          'New York, NY 10007',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.71490950153982,
#           'lng': -74.00948027011903}],
#         'lat': 40.71490950153982,
#         'lng': -74.00948027011903,
#         'postalCode': '10007',
#         'state': 'NY'},
#        'name': 'The Mysterious Bookshop',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-48510cf9f964a520a5501fe3-17',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d157941735',
#          'name': 'New American Restaurant',
#          'pluralName': 'New American Restaurants',
#          'primary': True,
#          'shortName': 'New American'}],
#        'id': '48510cf9f964a520a5501fe3',
#        'location': {'address': '134 Reade St',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'btwn Hudson and Greenwich St',
#         'distance': 133,
#         'formattedAddress': ['134 Reade St (btwn Hudson and Greenwich St)',
#          'New York, NY 10013',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.71637984317071,
#           'lng': -74.00962933453428}],
#         'lat': 40.71637984317071,
#         'lng': -74.00962933453428,
#         'postalCode': '10013',
#         'state': 'NY'},
#        'name': 'Restaurant Marc Forgione',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-51df85c9498edb5ea3ad2e2a-18',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'primary': True,
#          'shortName': 'Asian'}],
#        'id': '51df85c9498edb5ea3ad2e2a',
#        'location': {'address': '157 Duane Street',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'btwn Hudson St & W Broadway',
#         'distance': 159,
#         'formattedAddress': ['157 Duane Street (btwn Hudson St & W Broadway)',
#          'New York, NY 10013',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.716752816876635,
#           'lng': -74.00858376295221}],
#         'lat': 40.716752816876635,
#         'lng': -74.00858376295221,
#         'postalCode': '10013',
#         'state': 'NY'},
#        'name': 'Khe-Yo',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '350356912'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ad79413f964a520610c21e3-19',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'primary': True,
#          'shortName': 'Yoga Studio'}],
#        'id': '4ad79413f964a520610c21e3',
#        'location': {'address': '28 Warren St',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'Church St',
#         'distance': 127,
#         'formattedAddress': ['28 Warren St (Church St)',
#          'New York, NY 10007',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.714342290158086,
#           'lng': -74.00809356840004}],
#         'lat': 40.714342290158086,
#         'lng': -74.00809356840004,
#         'postalCode': '10007',
#         'state': 'NY'},
#        'name': 'Kula Yoga Project',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ce2a27cd58c60fc0fa1a76f-20',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/nailsalon_',
#           'suffix': '.png'},
#          'id': '4f04aa0c2fb6e1c99f3db0b8',
#          'name': 'Nail Salon',
#          'pluralName': 'Nail Salons',
#          'primary': True,
#          'shortName': 'Nail Salon'}],
#        'id': '4ce2a27cd58c60fc0fa1a76f',
#        'location': {'address': '112 Reade St',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'distance': 68,
#         'formattedAddress': ['112 Reade St',
#          'New York, NY 10013',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.71594125566931,
#           'lng': -74.00872053564494}],
#         'lat': 40.71594125566931,
#         'lng': -74.00872053564494,
#         'postalCode': '10013',
#         'state': 'NY'},
#        'name': 'Ten Over Ten',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '80843792'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-50597c5ce4b05ea41644ac74-21',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'primary': True,
#          'shortName': 'Sushi'}],
#        'delivery': {'id': '1170790',
#         'provider': {'icon': {'name': '/delivery_provider_seamless_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'seamless'},
#         'url': 'https://www.seamless.com/menu/sushi-of-gari-130-w-broadway-new-york/1170790?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1170790'},
#        'id': '50597c5ce4b05ea41644ac74',
#        'location': {'address': '130 W Broadway',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'Duane St.',
#         'distance': 155,
#         'formattedAddress': ['130 W Broadway (Duane St.)',
#          'New York, NY 10013',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.71668439227822,
#           'lng': -74.00834342869238}],
#         'lat': 40.71668439227822,
#         'lng': -74.00834342869238,
#         'postalCode': '10013',
#         'state': 'NY'},
#        'name': 'Sushi of Gari Tribeca',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5ae28a7b15173e002cef3271-22',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d11e941735',
#          'name': 'Cocktail Bar',
#          'pluralName': 'Cocktail Bars',
#          'primary': True,
#          'shortName': 'Cocktail'}],
#        'id': '5ae28a7b15173e002cef3271',
#        'location': {'address': '129 Chambers St.',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'West Broadway',
#         'distance': 21,
#         'formattedAddress': ['129 Chambers St. (West Broadway)',
#          'New York, NY 10007',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.71550092965859,
#           'lng': -74.00897677392395}],
#         'lat': 40.71550092965859,
#         'lng': -74.00897677392395,
#         'neighborhood': 'Tribeca',
#         'postalCode': '10007',
#         'state': 'NY'},
#        'name': 'Primo’s',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-534c9d7b498e1bdd443a40e1-23',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'primary': True,
#          'shortName': 'French'}],
#        'id': '534c9d7b498e1bdd443a40e1',
#        'location': {'address': '94 Chambers St',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'distance': 125,
#         'formattedAddress': ['94 Chambers St',
#          'New York, NY 10007',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.714754151461236,
#           'lng': -74.0075806002039}],
#         'lat': 40.714754151461236,
#         'lng': -74.0075806002039,
#         'postalCode': '10007',
#         'state': 'NY'},
#        'name': 'Racines',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-3fd66200f964a52083e61ee3-24',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'primary': True,
#          'shortName': 'French'}],
#        'delivery': {'id': '296531',
#         'provider': {'icon': {'name': '/delivery_provider_seamless_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'seamless'},
#         'url': 'https://www.seamless.com/menu/odeon-delivery-145-w-broadway-ave-new-york/296531?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=296531'},
#        'id': '3fd66200f964a52083e61ee3',
#        'location': {'address': '145 W Broadway',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'at Thomas St',
#         'distance': 198,
#         'formattedAddress': ['145 W Broadway (at Thomas St)',
#          'New York, NY 10013',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.71701011409906,
#           'lng': -74.00804244562225}],
#         'lat': 40.71701011409906,
#         'lng': -74.00804244562225,
#         'postalCode': '10013',
#         'state': 'NY'},
#        'name': 'The Odeon',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '97281190'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-49efcc88f964a52006691fe3-25',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'primary': True,
#          'shortName': 'Hotel'}],
#        'id': '49efcc88f964a52006691fe3',
#        'location': {'address': '85 W Broadway',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'Chambers St',
#         'distance': 35,
#         'formattedAddress': ['85 W Broadway (Chambers St)',
#          'New York, NY 10007',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.7151439,
#           'lng': -74.0091826}],
#         'lat': 40.7151439,
#         'lng': -74.0091826,
#         'postalCode': '10007',
#         'state': 'NY'},
#        'name': 'Smyth Hotel',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4a4baaf8f964a52091ac1fe3-26',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bagels_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d179941735',
#          'name': 'Bagel Shop',
#          'pluralName': 'Bagel Shops',
#          'primary': True,
#          'shortName': 'Bagels'}],
#        'delivery': {'id': '277435',
#         'provider': {'icon': {'name': '/delivery_provider_seamless_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'seamless'},
#         'url': 'https://www.seamless.com/menu/zuckers-bagels-and-smoked-fish-146-chambers-st-new-york/277435?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=277435'},
#        'id': '4a4baaf8f964a52091ac1fe3',
#        'location': {'address': '146 Chambers St',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'btwn W. Broadway & Greenwich St',
#         'distance': 88,
#         'formattedAddress': ['146 Chambers St (btwn W. Broadway & Greenwich St)',
#          'New York, NY 10007',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.71558,
#           'lng': -74.00985}],
#         'lat': 40.71558,
#         'lng': -74.00985,
#         'postalCode': '10007',
#         'state': 'NY'},
#        'name': "Zucker's Bagels & Smoked Fish",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4a411ea5f964a520cba41fe3-27',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d11e941735',
#          'name': 'Cocktail Bar',
#          'pluralName': 'Cocktail Bars',
#          'primary': True,
#          'shortName': 'Cocktail'}],
#        'id': '4a411ea5f964a520cba41fe3',
#        'location': {'address': '111 Reade St',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'btwn W Broadway & Church St',
#         'distance': 62,
#         'formattedAddress': ['111 Reade St (btwn W Broadway & Church St)',
#          'New York, NY 10013',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.715885126086015,
#           'lng': -74.00871361902418}],
#         'lat': 40.715885126086015,
#         'lng': -74.00871361902418,
#         'postalCode': '10013',
#         'state': 'NY'},
#        'name': 'Ward III',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '49730823'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b89c239f964a5206f4d32e3-28',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_kids_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d105951735',
#          'name': 'Kids Store',
#          'pluralName': 'Kids Stores',
#          'primary': True,
#          'shortName': 'Kids Store'}],
#        'id': '4b89c239f964a5206f4d32e3',
#        'location': {'address': '66 W Broadway',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'btw Murray & Warren',
#         'distance': 93,
#         'formattedAddress': ['66 W Broadway (btw Murray & Warren)',
#          'New York, NY 10007',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.71496319791811,
#           'lng': -74.00983873835128}],
#         'lat': 40.71496319791811,
#         'lng': -74.00983873835128,
#         'postalCode': '10007',
#         'state': 'NY'},
#        'name': 'Babesta',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4cc368704fcfbfb70a0cbe24-29',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_kids_',
#           'suffix': '.png'},
#          'id': '52f2ab2ebcbc57f1066b8b32',
#          'name': 'Baby Store',
#          'pluralName': 'Baby Stores',
#          'primary': True,
#          'shortName': 'Baby Store'}],
#        'id': '4cc368704fcfbfb70a0cbe24',
#        'location': {'address': '56 Warren Street',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'btw West Broadway & Church',
#         'distance': 73,
#         'formattedAddress': ['56 Warren Street (btw West Broadway & Church)',
#          'New York, NY 10007',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.71476,
#           'lng': -74.00928}],
#         'lat': 40.71476,
#         'lng': -74.00928,
#         'postalCode': '10007',
#         'state': 'NY'},
#        'name': 'Babesta',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '33736519'}}}],
#     'name': 'recommended',
#     'type': 'Recommended Places'}],
#   'headerFullLocation': 'Tribeca, New York',
#   'headerLocation': 'Tribeca',
#   'headerLocationGranularity': 'neighborhood',
#   'suggestedBounds': {'ne': {'lat': 40.7198370045, 'lng': -74.00292208843348},
#    'sw': {'lat': 40.710836995499996, 'lng': -74.01477391156652}},
#   'suggestedFilters': {'filters': [{'key': 'price', 'name': '$-$$$$'},
#     {'key': 'openNow', 'name': 'Open now'}],
#    'header': 'Tap to show:'},
#   'totalResults': 185}}

# %%
import requests

# %%
results = requests.get(url).json()
'There are {} around Ecco restaurant.'.format(len(results['response']['groups'][0]['items']))
# Out:
# 'There are 30 around Ecco restaurant.'

# %%
items = results['response']['groups'][0]['items']
items[0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'reasonName': 'globalInteractionReason',
#     'summary': 'This spot is popular',
#     'type': 'general'}]},
#  'referralId': 'e-0-4af5d65ff964a52091fd21e3-0',
#  'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#      'suffix': '.png'},
#     'id': '4bf58dd8d48988d1f8941735',
#     'name': 'Furniture / Home Store',
#     'pluralName': 'Furniture / Home Stores',
#     'primary': True,
#     'shortName': 'Furniture / Home'}],
#   'id': '4af5d65ff964a52091fd21e3',
#   'location': {'address': '57 Warren St',
#    'cc': 'US',
#    'city': 'New York',
#    'country': 'United States',
#    'crossStreet': 'Church St',
#    'distance': 73,
#    'formattedAddress': ['57 Warren St (Church St)',
#     'New York, NY 10007',
#     'United States'],
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.71482437714839,
#      'lng': -74.00940425461492}],
#    'lat': 40.71482437714839,
#    'lng': -74.00940425461492,
#    'neighborhood': 'Tribeca',
#    'postalCode': '10007',
#    'state': 'NY'},
#   'name': 'Korin',
#   'photos': {'count': 0, 'groups': []},
#   'venuePage': {'id': '33104775'}}}

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-f3f0320f5277> in <module>()
#       1 # keep only columns that include venue name, and anything that is associated with location
#       2 filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
# ----> 3 dataframe_filtered = dataframe.loc[:, filtered_columns]
#       4
#       5 # function that extracts the category of the venue
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1365             except (KeyError, IndexError):
#    1366                 pass
# -> 1367             return self._getitem_tuple(key)
#    1368         else:
#    1369             # we by definition only have the 0th axis
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#     861
#     862         # no multi-index, so validate all of the indexers
# --> 863         self._has_valid_tuple(tup)
#     864
#     865         # ugly hack for GH #836
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/pandas/core/indexing.py in _has_valid_tuple(self, key)
#     202             if i >= self.obj.ndim:
#     203                 raise IndexingError('Too many indexers')
# --> 204             if not self._has_valid_type(k, i):
#     205                 raise ValueError("Location based indexing can only have "
#     206                                  "[{types}] types"
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1470                         raise KeyError(
#    1471                             u"None of [{key}] are in the [{axis}]".format(
# -> 1472                                 key=key, axis=self.obj._get_axis_name(axis)))
#    1473                     else:
#    1474
#
# KeyError: "None of [['name', 'categories', 'id']] are in the [columns]"

# %%
dataframe.head()
# Out:
#    reasons.count                                      reasons.items  \
# 0              0  [{'type': 'general', 'reasonName': 'globalInte...
# 1              0  [{'type': 'general', 'reasonName': 'globalInte...
# 2              0  [{'type': 'general', 'reasonName': 'globalInte...
# 3              0  [{'type': 'general', 'reasonName': 'globalInte...
# 4              0  [{'type': 'general', 'reasonName': 'globalInte...
#
#                        referralId  \
# 0  e-0-4af5d65ff964a52091fd21e3-0
# 1  e-0-54148bc6498ea7bb8c05b70a-1
# 2  e-0-4c154c9a77cea593c401d260-2
# 3  e-0-4a8f2f39f964a520471420e3-3
# 4  e-0-4adcf23cf964a520cc6221e3-4
#
#                                     venue.categories venue.delivery.id  \
# 0  [{'name': 'Furniture / Home Store', 'id': '4bf...               NaN
# 1  [{'name': 'Vegetarian / Vegan Restaurant', 'id...               NaN
# 2  [{'name': 'Bakery', 'id': '4bf58dd8d48988d16a9...               NaN
# 3  [{'name': 'Sushi Restaurant', 'id': '4bf58dd8d...               NaN
# 4  [{'name': 'Wine Shop', 'id': '4bf58dd8d48988d1...               NaN
#
#   venue.delivery.provider.icon.name venue.delivery.provider.icon.prefix  \
# 0                               NaN                                 NaN
# 1                               NaN                                 NaN
# 2                               NaN                                 NaN
# 3                               NaN                                 NaN
# 4                               NaN                                 NaN
#
#   venue.delivery.provider.icon.sizes venue.delivery.provider.name  \
# 0                                NaN                          NaN
# 1                                NaN                          NaN
# 2                                NaN                          NaN
# 3                                NaN                          NaN
# 4                                NaN                          NaN
#
#   venue.delivery.url         ...          \
# 0                NaN         ...
# 1                NaN         ...
# 2                NaN         ...
# 3                NaN         ...
# 4                NaN         ...
#
#                        venue.location.labeledLatLngs venue.location.lat  \
# 0  [{'label': 'display', 'lng': -74.0094042546149...          40.714824
# 1  [{'label': 'display', 'lng': -74.0111317502157...          40.714788
# 2  [{'label': 'display', 'lng': -74.0088038953017...          40.713653
# 3  [{'label': 'display', 'lng': -74.0081010846620...          40.716526
# 4  [{'label': 'display', 'lng': -74.0097182331233...          40.715773
#
#   venue.location.lng venue.location.neighborhood venue.location.postalCode  \
# 0         -74.009404                     Tribeca                     10007
# 1         -74.011132                         NaN                     10007
# 2         -74.008804                         NaN                     10007
# 3         -74.008101                         NaN                     10013
# 4         -74.009718                         NaN                     10007
#
#   venue.location.state             venue.name venue.photos.count  \
# 0                   NY                  Korin                  0
# 1                   NY            Juice Press                  0
# 2                   NY       Takahachi Bakery                  0
# 3                   NY              Takahachi                  0
# 4                   NY  Chambers Street Wines                  0
#
#   venue.photos.groups  venue.venuePage.id
# 0                  []            33104775
# 1                  []                 NaN
# 2                  []            85495566
# 3                  []                 NaN
# 4                  []                 NaN
#
# [5 rows x 28 columns]

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-614172f4e411> in <module>()
#       1 # assign relevant part of JSON to venues
# ----> 2 venues = results['response']['venues']
#       3
#       4 # tranform venues into a dataframe
#       5 dataframe = json_normalize(venues)
#
# KeyError: 'venues'

# %%
dataframe = json_normalize(items) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-a980c5251693> in <module>()
#       6
#       7 # filter the category for each row
# ----> 8 dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)
#       9
#      10 # clean columns
#
# NameError: name 'get_category_type' is not defined
